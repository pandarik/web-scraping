# %% [markdown]
# # Module 12 Challenge
# ## Deliverable 2: Scrape and Analyze Mars Weather Data

# %%
# Import relevant libraries
from splinter import Browser
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import pandas as pd

# %%
browser = Browser('chrome')

# %% [markdown]
# ### Step 1: Visit the Website
#
# Use automated browsing to visit the [Mars Temperature Data Site](https://static.bc-edx.com/data/web/mars_facts/temperature.html). Inspect the page to identify which elements to scrape.
#
#    > **Hint** To identify which elements to scrape, you might want to inspect the page by using Chrome DevTools to discover whether the table contains usable classes.

# %%
# Visit the website
# https://static.bc-edx.com/data/web/mars_facts/temperature.html
url = "https://static.bc-edx.com/data/web/mars_facts/temperature.html"
browser.visit(url)

# %% [markdown]
# ### Step 2: Scrape the Table
#
# Create a Beautiful Soup object and use it to scrape the data in the HTML table.
#
# Note that this can also be achieved by using the Pandas `read_html` function. However, use Beautiful Soup here to continue sharpening your web scraping skills.

# %%
# Create a Beautiful Soup Object
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
# Find the table containing the Mars weather data
table = soup.find('table')

# Extract all rows of data
data = []
for row in table.find_all('tr')[1:]:
    cols = row.find_all('td')
    data.append({
        'id': cols[0].text,
        'terrestrial_date': cols[1].text,
        'sol': int(cols[2].text),
        'ls': float(cols[3].text),
        'month': cols[4].text,
        'min_temp': float(cols[5].text),
        'pressure': float(cols[6].text)
    })
    

# Display the list of rows
for row in data:
    print(row)
# Out:
# {'id': '2', 'terrestrial_date': '2012-08-16', 'sol': 10, 'ls': 155.0, 'month': '6', 'min_temp': -75.0, 'pressure': 739.0}
# {'id': '13', 'terrestrial_date': '2012-08-17', 'sol': 11, 'ls': 156.0, 'month': '6', 'min_temp': -76.0, 'pressure': 740.0}
# {'id': '24', 'terrestrial_date': '2012-08-18', 'sol': 12, 'ls': 156.0, 'month': '6', 'min_temp': -76.0, 'pressure': 741.0}
# {'id': '35', 'terrestrial_date': '2012-08-19', 'sol': 13, 'ls': 157.0, 'month': '6', 'min_temp': -74.0, 'pressure': 732.0}
# {'id': '46', 'terrestrial_date': '2012-08-20', 'sol': 14, 'ls': 157.0, 'month': '6', 'min_temp': -74.0, 'pressure': 740.0}
# {'id': '57', 'terrestrial_date': '2012-08-21', 'sol': 15, 'ls': 158.0, 'month': '6', 'min_temp': -78.0, 'pressure': 740.0}
# {'id': '68', 'terrestrial_date': '2012-08-22', 'sol': 16, 'ls': 158.0, 'month': '6', 'min_temp': -77.0, 'pressure': 740.0}
# {'id': '79', 'terrestrial_date': '2012-08-23', 'sol': 17, 'ls': 159.0, 'month': '6', 'min_temp': -76.0, 'pressure': 742.0}
# {'id': '112', 'terrestrial_date': '2012-08-27', 'sol': 21, 'ls': 161.0, 'month': '6', 'min_temp': -74.0, 'pressure': 741.0}
# {'id': '114', 'terrestrial_date': '2012-08-28', 'sol': 22, 'ls': 162.0, 'month': '6', 'min_temp': -74.0, 'pressure': 742.0}
# {'id': '123', 'terrestrial_date': '2012-08-29', 'sol': 23, 'ls': 162.0, 'month': '6', 'min_temp': -75.0, 'pressure': 741.0}
# {'id': '134', 'terrestrial_date': '2012-08-30', 'sol': 24, 'ls': 163.0, 'month': '6', 'min_temp': -75.0, 'pressure': 742.0}
# {'id': '145', 'terrestrial_date': '2012-08-31', 'sol': 25, 'ls': 163.0, 'month': '6', 'min_temp': -75.0, 'pressure': 743.0}
# {'id': '156', 'terrestrial_date': '2012-09-01', 'sol': 26, 'ls': 164.0, 'month': '6', 'min_temp': -76.0, 'pressure': 745.0}
# {'id': '163', 'terrestrial_date': '2012-09-02', 'sol': 27, 'ls': 164.0, 'month': '6', 'min_temp': -75.0, 'pressure': 743.0}
# {'id': '170', 'terrestrial_date': '2012-09-03', 'sol': 28, 'ls': 165.0, 'month': '6', 'min_temp': -75.0, 'pressure': 745.0}
# {'id': '171', 'terrestrial_date': '2012-09-04', 'sol': 29, 'ls': 166.0, 'month': '6', 'min_temp': -75.0, 'pressure': 747.0}
# {'id': '172', 'terrestrial_date': '2012-09-05', 'sol': 30, 'ls': 166.0, 'month': '6', 'min_temp': -74.0, 'pressure': 747.0}
# {'id': '173', 'terrestrial_date': '2012-09-06', 'sol': 31, 'ls': 167.0, 'month': '6', 'min_temp': -74.0, 'pressure': 745.0}
# {'id': '175', 'terrestrial_date': '2012-09-08', 'sol': 33, 'ls': 168.0, 'month': '6', 'min_temp': -73.0, 'pressure': 748.0}
# {'id': '176', 'terrestrial_date': '2012-09-10', 'sol': 34, 'ls': 168.0, 'month': '6', 'min_temp': -73.0, 'pressure': 748.0}
# {'id': '177', 'terrestrial_date': '2012-09-11', 'sol': 35, 'ls': 169.0, 'month': '6', 'min_temp': -73.0, 'pressure': 749.0}
# {'id': '178', 'terrestrial_date': '2012-09-12', 'sol': 36, 'ls': 169.0, 'month': '6', 'min_temp': -73.0, 'pressure': 750.0}
# {'id': '179', 'terrestrial_date': '2012-09-13', 'sol': 37, 'ls': 170.0, 'month': '6', 'min_temp': -73.0, 'pressure': 750.0}
# {'id': '180', 'terrestrial_date': '2012-09-14', 'sol': 38, 'ls': 171.0, 'month': '6', 'min_temp': -73.0, 'pressure': 750.0}
# {'id': '181', 'terrestrial_date': '2012-09-15', 'sol': 39, 'ls': 171.0, 'month': '6', 'min_temp': -75.0, 'pressure': 751.0}
# {'id': '182', 'terrestrial_date': '2012-09-16', 'sol': 40, 'ls': 172.0, 'month': '6', 'min_temp': -75.0, 'pressure': 753.0}
# {'id': '183', 'terrestrial_date': '2012-09-17', 'sol': 41, 'ls': 172.0, 'month': '6', 'min_temp': -75.0, 'pressure': 753.0}
# {'id': '184', 'terrestrial_date': '2012-09-18', 'sol': 42, 'ls': 173.0, 'month': '6', 'min_temp': -75.0, 'pressure': 754.0}
# {'id': '185', 'terrestrial_date': '2012-09-19', 'sol': 43, 'ls': 173.0, 'month': '6', 'min_temp': -74.0, 'pressure': 756.0}
# {'id': '186', 'terrestrial_date': '2012-09-20', 'sol': 44, 'ls': 174.0, 'month': '6', 'min_temp': -75.0, 'pressure': 757.0}
# {'id': '187', 'terrestrial_date': '2012-09-21', 'sol': 45, 'ls': 175.0, 'month': '6', 'min_temp': -74.0, 'pressure': 758.0}
# {'id': '188', 'terrestrial_date': '2012-09-22', 'sol': 46, 'ls': 175.0, 'month': '6', 'min_temp': -74.0, 'pressure': 758.0}
# {'id': '189', 'terrestrial_date': '2012-09-23', 'sol': 47, 'ls': 176.0, 'month': '6', 'min_temp': -75.0, 'pressure': 758.0}
# {'id': '190', 'terrestrial_date': '2012-09-24', 'sol': 48, 'ls': 176.0, 'month': '6', 'min_temp': -75.0, 'pressure': 759.0}
# {'id': '191', 'terrestrial_date': '2012-09-25', 'sol': 49, 'ls': 177.0, 'month': '6', 'min_temp': -74.0, 'pressure': 761.0}
# {'id': '192', 'terrestrial_date': '2012-09-26', 'sol': 50, 'ls': 177.0, 'month': '6', 'min_temp': -72.0, 'pressure': 761.0}
# {'id': '193', 'terrestrial_date': '2012-09-27', 'sol': 51, 'ls': 178.0, 'month': '6', 'min_temp': -76.0, 'pressure': 762.0}
# {'id': '194', 'terrestrial_date': '2012-09-28', 'sol': 52, 'ls': 179.0, 'month': '6', 'min_temp': -74.0, 'pressure': 762.0}
# {'id': '195', 'terrestrial_date': '2012-09-29', 'sol': 53, 'ls': 179.0, 'month': '6', 'min_temp': -71.0, 'pressure': 764.0}
# {'id': '196', 'terrestrial_date': '2012-09-30', 'sol': 54, 'ls': 180.0, 'month': '7', 'min_temp': -72.0, 'pressure': 766.0}
# {'id': '197', 'terrestrial_date': '2012-10-01', 'sol': 55, 'ls': 180.0, 'month': '7', 'min_temp': -74.0, 'pressure': 766.0}
# {'id': '198', 'terrestrial_date': '2012-10-02', 'sol': 56, 'ls': 181.0, 'month': '7', 'min_temp': -73.0, 'pressure': 768.0}
# {'id': '199', 'terrestrial_date': '2012-10-03', 'sol': 57, 'ls': 181.0, 'month': '7', 'min_temp': -73.0, 'pressure': 769.0}
# {'id': '200', 'terrestrial_date': '2012-10-04', 'sol': 58, 'ls': 182.0, 'month': '7', 'min_temp': -74.0, 'pressure': 769.0}
# {'id': '201', 'terrestrial_date': '2012-10-05', 'sol': 59, 'ls': 183.0, 'month': '7', 'min_temp': -76.0, 'pressure': 771.0}
# {'id': '202', 'terrestrial_date': '2012-10-06', 'sol': 60, 'ls': 183.0, 'month': '7', 'min_temp': -75.0, 'pressure': 772.0}
# {'id': '203', 'terrestrial_date': '2012-10-07', 'sol': 61, 'ls': 184.0, 'month': '7', 'min_temp': -72.0, 'pressure': 772.0}
# {'id': '204', 'terrestrial_date': '2012-10-08', 'sol': 62, 'ls': 184.0, 'month': '7', 'min_temp': -72.0, 'pressure': 774.0}
# {'id': '205', 'terrestrial_date': '2012-10-09', 'sol': 63, 'ls': 185.0, 'month': '7', 'min_temp': -73.0, 'pressure': 775.0}
# {'id': '206', 'terrestrial_date': '2012-10-10', 'sol': 64, 'ls': 186.0, 'month': '7', 'min_temp': -74.0, 'pressure': 776.0}
# {'id': '207', 'terrestrial_date': '2012-10-11', 'sol': 65, 'ls': 186.0, 'month': '7', 'min_temp': -72.0, 'pressure': 777.0}
# {'id': '208', 'terrestrial_date': '2012-10-12', 'sol': 66, 'ls': 187.0, 'month': '7', 'min_temp': -73.0, 'pressure': 778.0}
# {'id': '209', 'terrestrial_date': '2012-10-13', 'sol': 67, 'ls': 187.0, 'month': '7', 'min_temp': -73.0, 'pressure': 780.0}
# {'id': '210', 'terrestrial_date': '2012-10-14', 'sol': 68, 'ls': 188.0, 'month': '7', 'min_temp': -71.0, 'pressure': 781.0}
# {'id': '211', 'terrestrial_date': '2012-10-15', 'sol': 69, 'ls': 189.0, 'month': '7', 'min_temp': -73.0, 'pressure': 778.0}
# {'id': '212', 'terrestrial_date': '2012-10-17', 'sol': 70, 'ls': 189.0, 'month': '7', 'min_temp': -72.0, 'pressure': 783.0}
# {'id': '213', 'terrestrial_date': '2012-10-18', 'sol': 71, 'ls': 190.0, 'month': '7', 'min_temp': -71.0, 'pressure': 784.0}
# {'id': '214', 'terrestrial_date': '2012-10-19', 'sol': 72, 'ls': 190.0, 'month': '7', 'min_temp': -73.0, 'pressure': 785.0}
# {'id': '215', 'terrestrial_date': '2012-10-20', 'sol': 73, 'ls': 191.0, 'month': '7', 'min_temp': -70.0, 'pressure': 788.0}
# {'id': '216', 'terrestrial_date': '2012-10-21', 'sol': 74, 'ls': 192.0, 'month': '7', 'min_temp': -72.0, 'pressure': 790.0}
# {'id': '217', 'terrestrial_date': '2012-10-22', 'sol': 75, 'ls': 192.0, 'month': '7', 'min_temp': -73.0, 'pressure': 791.0}
# {'id': '218', 'terrestrial_date': '2012-10-23', 'sol': 76, 'ls': 193.0, 'month': '7', 'min_temp': -73.0, 'pressure': 792.0}
# {'id': '219', 'terrestrial_date': '2012-10-24', 'sol': 77, 'ls': 193.0, 'month': '7', 'min_temp': -71.0, 'pressure': 792.0}
# {'id': '220', 'terrestrial_date': '2012-10-25', 'sol': 78, 'ls': 194.0, 'month': '7', 'min_temp': -71.0, 'pressure': 793.0}
# {'id': '221', 'terrestrial_date': '2012-10-26', 'sol': 79, 'ls': 195.0, 'month': '7', 'min_temp': -73.0, 'pressure': 795.0}
# {'id': '222', 'terrestrial_date': '2012-10-27', 'sol': 80, 'ls': 195.0, 'month': '7', 'min_temp': -70.0, 'pressure': 796.0}
# {'id': '223', 'terrestrial_date': '2012-10-28', 'sol': 81, 'ls': 196.0, 'month': '7', 'min_temp': -72.0, 'pressure': 798.0}
# {'id': '224', 'terrestrial_date': '2012-10-29', 'sol': 82, 'ls': 196.0, 'month': '7', 'min_temp': -72.0, 'pressure': 799.0}
# {'id': '225', 'terrestrial_date': '2012-10-30', 'sol': 83, 'ls': 197.0, 'month': '7', 'min_temp': -72.0, 'pressure': 801.0}
# {'id': '226', 'terrestrial_date': '2012-10-31', 'sol': 84, 'ls': 198.0, 'month': '7', 'min_temp': -70.0, 'pressure': 801.0}
# {'id': '227', 'terrestrial_date': '2012-11-01', 'sol': 85, 'ls': 198.0, 'month': '7', 'min_temp': -71.0, 'pressure': 805.0}
# {'id': '228', 'terrestrial_date': '2012-11-02', 'sol': 86, 'ls': 199.0, 'month': '7', 'min_temp': -71.0, 'pressure': 808.0}
# {'id': '229', 'terrestrial_date': '2012-11-03', 'sol': 87, 'ls': 199.0, 'month': '7', 'min_temp': -70.0, 'pressure': 808.0}
# {'id': '230', 'terrestrial_date': '2012-11-04', 'sol': 88, 'ls': 200.0, 'month': '7', 'min_temp': -70.0, 'pressure': 811.0}
# {'id': '231', 'terrestrial_date': '2012-11-05', 'sol': 89, 'ls': 201.0, 'month': '7', 'min_temp': -73.0, 'pressure': 813.0}
# {'id': '233', 'terrestrial_date': '2012-11-06', 'sol': 90, 'ls': 201.0, 'month': '7', 'min_temp': -71.0, 'pressure': 813.0}
# {'id': '234', 'terrestrial_date': '2012-11-07', 'sol': 91, 'ls': 202.0, 'month': '7', 'min_temp': -74.0, 'pressure': 817.0}
# {'id': '235', 'terrestrial_date': '2012-11-08', 'sol': 92, 'ls': 202.0, 'month': '7', 'min_temp': -74.0, 'pressure': 820.0}
# {'id': '236', 'terrestrial_date': '2012-11-09', 'sol': 93, 'ls': 203.0, 'month': '7', 'min_temp': -72.0, 'pressure': 819.0}
# {'id': '237', 'terrestrial_date': '2012-11-10', 'sol': 94, 'ls': 204.0, 'month': '7', 'min_temp': -70.0, 'pressure': 822.0}
# {'id': '238', 'terrestrial_date': '2012-11-11', 'sol': 95, 'ls': 204.0, 'month': '7', 'min_temp': -68.0, 'pressure': 822.0}
# {'id': '239', 'terrestrial_date': '2012-11-12', 'sol': 96, 'ls': 205.0, 'month': '7', 'min_temp': -71.0, 'pressure': 826.0}
# {'id': '240', 'terrestrial_date': '2012-11-13', 'sol': 97, 'ls': 206.0, 'month': '7', 'min_temp': -68.0, 'pressure': 828.0}
# {'id': '241', 'terrestrial_date': '2012-11-14', 'sol': 98, 'ls': 206.0, 'month': '7', 'min_temp': -68.0, 'pressure': 828.0}
# {'id': '242', 'terrestrial_date': '2012-11-15', 'sol': 99, 'ls': 207.0, 'month': '7', 'min_temp': -68.0, 'pressure': 829.0}
# {'id': '3', 'terrestrial_date': '2012-11-16', 'sol': 100, 'ls': 207.0, 'month': '7', 'min_temp': -66.0, 'pressure': 829.0}
# {'id': '4', 'terrestrial_date': '2012-11-17', 'sol': 101, 'ls': 208.0, 'month': '7', 'min_temp': -65.0, 'pressure': 830.0}
# {'id': '5', 'terrestrial_date': '2012-11-18', 'sol': 102, 'ls': 209.0, 'month': '7', 'min_temp': -67.0, 'pressure': 833.0}
# {'id': '6', 'terrestrial_date': '2012-11-19', 'sol': 103, 'ls': 209.0, 'month': '7', 'min_temp': -66.0, 'pressure': 836.0}
# {'id': '7', 'terrestrial_date': '2012-11-20', 'sol': 104, 'ls': 210.0, 'month': '8', 'min_temp': -67.0, 'pressure': 838.0}
# {'id': '8', 'terrestrial_date': '2012-11-21', 'sol': 105, 'ls': 211.0, 'month': '8', 'min_temp': -66.0, 'pressure': 839.0}
# {'id': '9', 'terrestrial_date': '2012-11-23', 'sol': 106, 'ls': 211.0, 'month': '8', 'min_temp': -66.0, 'pressure': 841.0}
# {'id': '10', 'terrestrial_date': '2012-11-24', 'sol': 107, 'ls': 212.0, 'month': '8', 'min_temp': -66.0, 'pressure': 844.0}
# {'id': '11', 'terrestrial_date': '2012-11-25', 'sol': 108, 'ls': 212.0, 'month': '8', 'min_temp': -65.0, 'pressure': 845.0}
# {'id': '12', 'terrestrial_date': '2012-11-26', 'sol': 109, 'ls': 213.0, 'month': '8', 'min_temp': -64.0, 'pressure': 844.0}
# {'id': '14', 'terrestrial_date': '2012-11-27', 'sol': 110, 'ls': 214.0, 'month': '8', 'min_temp': -65.0, 'pressure': 848.0}
# {'id': '15', 'terrestrial_date': '2012-11-28', 'sol': 111, 'ls': 214.0, 'month': '8', 'min_temp': -66.0, 'pressure': 849.0}
# {'id': '16', 'terrestrial_date': '2012-11-29', 'sol': 112, 'ls': 215.0, 'month': '8', 'min_temp': -65.0, 'pressure': 852.0}
# {'id': '17', 'terrestrial_date': '2012-11-30', 'sol': 113, 'ls': 216.0, 'month': '8', 'min_temp': -66.0, 'pressure': 857.0}
# {'id': '18', 'terrestrial_date': '2012-12-01', 'sol': 114, 'ls': 216.0, 'month': '8', 'min_temp': -69.0, 'pressure': 857.0}
# {'id': '19', 'terrestrial_date': '2012-12-02', 'sol': 115, 'ls': 217.0, 'month': '8', 'min_temp': -66.0, 'pressure': 857.0}
# {'id': '20', 'terrestrial_date': '2012-12-03', 'sol': 116, 'ls': 217.0, 'month': '8', 'min_temp': -67.0, 'pressure': 859.0}
# {'id': '21', 'terrestrial_date': '2012-12-04', 'sol': 117, 'ls': 218.0, 'month': '8', 'min_temp': -66.0, 'pressure': 861.0}
# {'id': '22', 'terrestrial_date': '2012-12-05', 'sol': 118, 'ls': 219.0, 'month': '8', 'min_temp': -65.0, 'pressure': 864.0}
# {'id': '23', 'terrestrial_date': '2012-12-06', 'sol': 119, 'ls': 219.0, 'month': '8', 'min_temp': -66.0, 'pressure': 866.0}
# {'id': '25', 'terrestrial_date': '2012-12-07', 'sol': 120, 'ls': 220.0, 'month': '8', 'min_temp': -67.0, 'pressure': 867.0}
# {'id': '26', 'terrestrial_date': '2012-12-08', 'sol': 121, 'ls': 221.0, 'month': '8', 'min_temp': -66.0, 'pressure': 869.0}
# {'id': '27', 'terrestrial_date': '2012-12-09', 'sol': 122, 'ls': 221.0, 'month': '8', 'min_temp': -65.0, 'pressure': 869.0}
# {'id': '28', 'terrestrial_date': '2012-12-10', 'sol': 123, 'ls': 222.0, 'month': '8', 'min_temp': -66.0, 'pressure': 875.0}
# {'id': '29', 'terrestrial_date': '2012-12-11', 'sol': 124, 'ls': 223.0, 'month': '8', 'min_temp': -66.0, 'pressure': 876.0}
# {'id': '30', 'terrestrial_date': '2012-12-12', 'sol': 125, 'ls': 223.0, 'month': '8', 'min_temp': -68.0, 'pressure': 880.0}
# {'id': '31', 'terrestrial_date': '2012-12-13', 'sol': 126, 'ls': 224.0, 'month': '8', 'min_temp': -66.0, 'pressure': 880.0}
# {'id': '32', 'terrestrial_date': '2012-12-14', 'sol': 127, 'ls': 224.0, 'month': '8', 'min_temp': -67.0, 'pressure': 884.0}
# {'id': '33', 'terrestrial_date': '2012-12-15', 'sol': 128, 'ls': 225.0, 'month': '8', 'min_temp': -67.0, 'pressure': 883.0}
# {'id': '34', 'terrestrial_date': '2012-12-16', 'sol': 129, 'ls': 226.0, 'month': '8', 'min_temp': -65.0, 'pressure': 886.0}
# {'id': '36', 'terrestrial_date': '2012-12-17', 'sol': 130, 'ls': 226.0, 'month': '8', 'min_temp': -65.0, 'pressure': 888.0}
# {'id': '37', 'terrestrial_date': '2012-12-18', 'sol': 131, 'ls': 227.0, 'month': '8', 'min_temp': -65.0, 'pressure': 889.0}
# {'id': '38', 'terrestrial_date': '2012-12-19', 'sol': 132, 'ls': 228.0, 'month': '8', 'min_temp': -65.0, 'pressure': 890.0}
# {'id': '39', 'terrestrial_date': '2012-12-20', 'sol': 133, 'ls': 228.0, 'month': '8', 'min_temp': -65.0, 'pressure': 891.0}
# {'id': '40', 'terrestrial_date': '2012-12-21', 'sol': 134, 'ls': 229.0, 'month': '8', 'min_temp': -67.0, 'pressure': 893.0}
# {'id': '41', 'terrestrial_date': '2012-12-22', 'sol': 135, 'ls': 230.0, 'month': '8', 'min_temp': -65.0, 'pressure': 894.0}
# {'id': '42', 'terrestrial_date': '2012-12-23', 'sol': 136, 'ls': 230.0, 'month': '8', 'min_temp': -65.0, 'pressure': 897.0}
# {'id': '43', 'terrestrial_date': '2012-12-24', 'sol': 137, 'ls': 231.0, 'month': '8', 'min_temp': -64.0, 'pressure': 896.0}
# {'id': '44', 'terrestrial_date': '2012-12-25', 'sol': 138, 'ls': 232.0, 'month': '8', 'min_temp': -65.0, 'pressure': 899.0}
# {'id': '45', 'terrestrial_date': '2012-12-26', 'sol': 139, 'ls': 232.0, 'month': '8', 'min_temp': -66.0, 'pressure': 899.0}
# {'id': '47', 'terrestrial_date': '2012-12-27', 'sol': 140, 'ls': 233.0, 'month': '8', 'min_temp': -66.0, 'pressure': 903.0}
# {'id': '48', 'terrestrial_date': '2012-12-28', 'sol': 141, 'ls': 233.0, 'month': '8', 'min_temp': -64.0, 'pressure': 904.0}
# {'id': '49', 'terrestrial_date': '2012-12-29', 'sol': 142, 'ls': 234.0, 'month': '8', 'min_temp': -65.0, 'pressure': 906.0}
# {'id': '50', 'terrestrial_date': '2012-12-31', 'sol': 143, 'ls': 235.0, 'month': '8', 'min_temp': -63.0, 'pressure': 908.0}
# {'id': '51', 'terrestrial_date': '2013-01-01', 'sol': 144, 'ls': 235.0, 'month': '8', 'min_temp': -64.0, 'pressure': 907.0}
# {'id': '52', 'terrestrial_date': '2013-01-02', 'sol': 145, 'ls': 236.0, 'month': '8', 'min_temp': -64.0, 'pressure': 909.0}
# {'id': '53', 'terrestrial_date': '2013-01-03', 'sol': 146, 'ls': 237.0, 'month': '8', 'min_temp': -65.0, 'pressure': 908.0}
# {'id': '54', 'terrestrial_date': '2013-01-04', 'sol': 147, 'ls': 237.0, 'month': '8', 'min_temp': -65.0, 'pressure': 914.0}
# {'id': '55', 'terrestrial_date': '2013-01-05', 'sol': 148, 'ls': 238.0, 'month': '8', 'min_temp': -65.0, 'pressure': 912.0}
# {'id': '56', 'terrestrial_date': '2013-01-06', 'sol': 149, 'ls': 239.0, 'month': '8', 'min_temp': -65.0, 'pressure': 914.0}
# {'id': '58', 'terrestrial_date': '2013-01-07', 'sol': 150, 'ls': 239.0, 'month': '8', 'min_temp': -64.0, 'pressure': 913.0}
# {'id': '59', 'terrestrial_date': '2013-01-08', 'sol': 151, 'ls': 240.0, 'month': '9', 'min_temp': -65.0, 'pressure': 915.0}
# {'id': '60', 'terrestrial_date': '2013-01-09', 'sol': 152, 'ls': 241.0, 'month': '9', 'min_temp': -63.0, 'pressure': 914.0}
# {'id': '61', 'terrestrial_date': '2013-01-10', 'sol': 153, 'ls': 241.0, 'month': '9', 'min_temp': -65.0, 'pressure': 915.0}
# {'id': '62', 'terrestrial_date': '2013-01-11', 'sol': 154, 'ls': 242.0, 'month': '9', 'min_temp': -65.0, 'pressure': 917.0}
# {'id': '63', 'terrestrial_date': '2013-01-12', 'sol': 155, 'ls': 243.0, 'month': '9', 'min_temp': -64.0, 'pressure': 917.0}
# {'id': '64', 'terrestrial_date': '2013-01-13', 'sol': 156, 'ls': 243.0, 'month': '9', 'min_temp': -65.0, 'pressure': 922.0}
# {'id': '65', 'terrestrial_date': '2013-01-14', 'sol': 157, 'ls': 244.0, 'month': '9', 'min_temp': -64.0, 'pressure': 920.0}
# {'id': '66', 'terrestrial_date': '2013-01-15', 'sol': 158, 'ls': 245.0, 'month': '9', 'min_temp': -66.0, 'pressure': 922.0}
# {'id': '67', 'terrestrial_date': '2013-01-16', 'sol': 159, 'ls': 245.0, 'month': '9', 'min_temp': -65.0, 'pressure': 918.0}
# {'id': '69', 'terrestrial_date': '2013-01-17', 'sol': 160, 'ls': 246.0, 'month': '9', 'min_temp': -67.0, 'pressure': 919.0}
# {'id': '70', 'terrestrial_date': '2013-01-18', 'sol': 161, 'ls': 246.0, 'month': '9', 'min_temp': -65.0, 'pressure': 919.0}
# {'id': '71', 'terrestrial_date': '2013-01-19', 'sol': 162, 'ls': 247.0, 'month': '9', 'min_temp': -65.0, 'pressure': 919.0}
# {'id': '72', 'terrestrial_date': '2013-01-20', 'sol': 163, 'ls': 248.0, 'month': '9', 'min_temp': -65.0, 'pressure': 919.0}
# {'id': '73', 'terrestrial_date': '2013-01-21', 'sol': 164, 'ls': 248.0, 'month': '9', 'min_temp': -64.0, 'pressure': 919.0}
# {'id': '74', 'terrestrial_date': '2013-01-22', 'sol': 165, 'ls': 249.0, 'month': '9', 'min_temp': -65.0, 'pressure': 922.0}
# {'id': '75', 'terrestrial_date': '2013-01-23', 'sol': 166, 'ls': 250.0, 'month': '9', 'min_temp': -65.0, 'pressure': 922.0}
# {'id': '76', 'terrestrial_date': '2013-01-24', 'sol': 167, 'ls': 250.0, 'month': '9', 'min_temp': -65.0, 'pressure': 920.0}
# {'id': '77', 'terrestrial_date': '2013-01-25', 'sol': 168, 'ls': 251.0, 'month': '9', 'min_temp': -66.0, 'pressure': 923.0}
# {'id': '78', 'terrestrial_date': '2013-01-26', 'sol': 169, 'ls': 252.0, 'month': '9', 'min_temp': -66.0, 'pressure': 922.0}
# {'id': '80', 'terrestrial_date': '2013-01-27', 'sol': 170, 'ls': 252.0, 'month': '9', 'min_temp': -66.0, 'pressure': 925.0}
# {'id': '81', 'terrestrial_date': '2013-01-28', 'sol': 171, 'ls': 253.0, 'month': '9', 'min_temp': -67.0, 'pressure': 925.0}
# {'id': '82', 'terrestrial_date': '2013-01-29', 'sol': 172, 'ls': 254.0, 'month': '9', 'min_temp': -67.0, 'pressure': 923.0}
# {'id': '83', 'terrestrial_date': '2013-01-30', 'sol': 173, 'ls': 254.0, 'month': '9', 'min_temp': -67.0, 'pressure': 920.0}
# {'id': '84', 'terrestrial_date': '2013-01-31', 'sol': 174, 'ls': 255.0, 'month': '9', 'min_temp': -67.0, 'pressure': 921.0}
# {'id': '85', 'terrestrial_date': '2013-02-01', 'sol': 175, 'ls': 256.0, 'month': '9', 'min_temp': -68.0, 'pressure': 921.0}
# {'id': '86', 'terrestrial_date': '2013-02-02', 'sol': 176, 'ls': 256.0, 'month': '9', 'min_temp': -67.0, 'pressure': 920.0}
# {'id': '87', 'terrestrial_date': '2013-02-03', 'sol': 177, 'ls': 257.0, 'month': '9', 'min_temp': -66.0, 'pressure': 921.0}
# {'id': '88', 'terrestrial_date': '2013-02-04', 'sol': 178, 'ls': 258.0, 'month': '9', 'min_temp': -66.0, 'pressure': 920.0}
# {'id': '89', 'terrestrial_date': '2013-02-06', 'sol': 179, 'ls': 258.0, 'month': '9', 'min_temp': -66.0, 'pressure': 920.0}
# {'id': '91', 'terrestrial_date': '2013-02-07', 'sol': 180, 'ls': 259.0, 'month': '9', 'min_temp': -67.0, 'pressure': 919.0}
# {'id': '92', 'terrestrial_date': '2013-02-08', 'sol': 181, 'ls': 260.0, 'month': '9', 'min_temp': -67.0, 'pressure': 918.0}
# {'id': '93', 'terrestrial_date': '2013-02-09', 'sol': 182, 'ls': 260.0, 'month': '9', 'min_temp': -67.0, 'pressure': 921.0}
# {'id': '94', 'terrestrial_date': '2013-02-10', 'sol': 183, 'ls': 261.0, 'month': '9', 'min_temp': -67.0, 'pressure': 921.0}
# {'id': '95', 'terrestrial_date': '2013-02-11', 'sol': 184, 'ls': 261.0, 'month': '9', 'min_temp': -67.0, 'pressure': 923.0}
# {'id': '96', 'terrestrial_date': '2013-02-12', 'sol': 185, 'ls': 262.0, 'month': '9', 'min_temp': -67.0, 'pressure': 923.0}
# {'id': '97', 'terrestrial_date': '2013-02-13', 'sol': 186, 'ls': 263.0, 'month': '9', 'min_temp': -66.0, 'pressure': 922.0}
# {'id': '98', 'terrestrial_date': '2013-02-14', 'sol': 187, 'ls': 263.0, 'month': '9', 'min_temp': -67.0, 'pressure': 921.0}
# {'id': '99', 'terrestrial_date': '2013-02-15', 'sol': 188, 'ls': 264.0, 'month': '9', 'min_temp': -68.0, 'pressure': 920.0}
# {'id': '100', 'terrestrial_date': '2013-02-16', 'sol': 189, 'ls': 265.0, 'month': '9', 'min_temp': -68.0, 'pressure': 920.0}
# {'id': '102', 'terrestrial_date': '2013-02-17', 'sol': 190, 'ls': 265.0, 'month': '9', 'min_temp': -66.0, 'pressure': 917.0}
# {'id': '103', 'terrestrial_date': '2013-02-18', 'sol': 191, 'ls': 266.0, 'month': '9', 'min_temp': -67.0, 'pressure': 921.0}
# {'id': '106', 'terrestrial_date': '2013-02-23', 'sol': 196, 'ls': 269.0, 'month': '9', 'min_temp': -66.0, 'pressure': 916.0}
# {'id': '107', 'terrestrial_date': '2013-02-24', 'sol': 197, 'ls': 270.0, 'month': '10', 'min_temp': -68.0, 'pressure': 915.0}
# {'id': '108', 'terrestrial_date': '2013-02-25', 'sol': 198, 'ls': 271.0, 'month': '10', 'min_temp': -67.0, 'pressure': 914.0}
# {'id': '109', 'terrestrial_date': '2013-02-26', 'sol': 199, 'ls': 271.0, 'month': '10', 'min_temp': -66.0, 'pressure': 917.0}
# {'id': '116', 'terrestrial_date': '2013-03-23', 'sol': 223, 'ls': 287.0, 'month': '10', 'min_temp': -71.0, 'pressure': 895.0}
# {'id': '117', 'terrestrial_date': '2013-03-24', 'sol': 224, 'ls': 287.0, 'month': '10', 'min_temp': -69.0, 'pressure': 894.0}
# {'id': '118', 'terrestrial_date': '2013-03-25', 'sol': 225, 'ls': 288.0, 'month': '10', 'min_temp': -71.0, 'pressure': 894.0}
# {'id': '119', 'terrestrial_date': '2013-03-26', 'sol': 226, 'ls': 288.0, 'month': '10', 'min_temp': -70.0, 'pressure': 894.0}
# {'id': '120', 'terrestrial_date': '2013-03-27', 'sol': 227, 'ls': 289.0, 'month': '10', 'min_temp': -70.0, 'pressure': 892.0}
# {'id': '121', 'terrestrial_date': '2013-03-28', 'sol': 228, 'ls': 290.0, 'month': '10', 'min_temp': -71.0, 'pressure': 894.0}
# {'id': '122', 'terrestrial_date': '2013-03-29', 'sol': 229, 'ls': 290.0, 'month': '10', 'min_temp': -69.0, 'pressure': 894.0}
# {'id': '124', 'terrestrial_date': '2013-03-30', 'sol': 230, 'ls': 291.0, 'month': '10', 'min_temp': -69.0, 'pressure': 888.0}
# {'id': '125', 'terrestrial_date': '2013-03-31', 'sol': 231, 'ls': 292.0, 'month': '10', 'min_temp': -71.0, 'pressure': 890.0}
# {'id': '126', 'terrestrial_date': '2013-04-01', 'sol': 232, 'ls': 292.0, 'month': '10', 'min_temp': -69.0, 'pressure': 888.0}
# {'id': '127', 'terrestrial_date': '2013-04-02', 'sol': 233, 'ls': 293.0, 'month': '10', 'min_temp': -69.0, 'pressure': 889.0}
# {'id': '128', 'terrestrial_date': '2013-04-03', 'sol': 234, 'ls': 293.0, 'month': '10', 'min_temp': -69.0, 'pressure': 890.0}
# {'id': '129', 'terrestrial_date': '2013-04-04', 'sol': 235, 'ls': 294.0, 'month': '10', 'min_temp': -70.0, 'pressure': 886.0}
# {'id': '130', 'terrestrial_date': '2013-04-05', 'sol': 236, 'ls': 295.0, 'month': '10', 'min_temp': -72.0, 'pressure': 886.0}
# {'id': '131', 'terrestrial_date': '2013-04-06', 'sol': 237, 'ls': 295.0, 'month': '10', 'min_temp': -71.0, 'pressure': 883.0}
# {'id': '132', 'terrestrial_date': '2013-04-07', 'sol': 238, 'ls': 296.0, 'month': '10', 'min_temp': -70.0, 'pressure': 885.0}
# {'id': '133', 'terrestrial_date': '2013-04-08', 'sol': 239, 'ls': 297.0, 'month': '10', 'min_temp': -73.0, 'pressure': 885.0}
# {'id': '135', 'terrestrial_date': '2013-04-09', 'sol': 240, 'ls': 297.0, 'month': '10', 'min_temp': -70.0, 'pressure': 884.0}
# {'id': '136', 'terrestrial_date': '2013-04-10', 'sol': 241, 'ls': 298.0, 'month': '10', 'min_temp': -72.0, 'pressure': 884.0}
# {'id': '137', 'terrestrial_date': '2013-04-11', 'sol': 242, 'ls': 298.0, 'month': '10', 'min_temp': -70.0, 'pressure': 881.0}
# {'id': '138', 'terrestrial_date': '2013-04-12', 'sol': 243, 'ls': 299.0, 'month': '10', 'min_temp': -71.0, 'pressure': 884.0}
# {'id': '139', 'terrestrial_date': '2013-04-13', 'sol': 244, 'ls': 300.0, 'month': '11', 'min_temp': -69.0, 'pressure': 878.0}
# {'id': '140', 'terrestrial_date': '2013-04-14', 'sol': 245, 'ls': 300.0, 'month': '11', 'min_temp': -70.0, 'pressure': 879.0}
# {'id': '141', 'terrestrial_date': '2013-04-15', 'sol': 246, 'ls': 301.0, 'month': '11', 'min_temp': -73.0, 'pressure': 878.0}
# {'id': '142', 'terrestrial_date': '2013-04-16', 'sol': 247, 'ls': 301.0, 'month': '11', 'min_temp': -71.0, 'pressure': 873.0}
# {'id': '143', 'terrestrial_date': '2013-04-17', 'sol': 248, 'ls': 302.0, 'month': '11', 'min_temp': -70.0, 'pressure': 877.0}
# {'id': '144', 'terrestrial_date': '2013-04-18', 'sol': 249, 'ls': 303.0, 'month': '11', 'min_temp': -69.0, 'pressure': 873.0}
# {'id': '146', 'terrestrial_date': '2013-04-19', 'sol': 250, 'ls': 303.0, 'month': '11', 'min_temp': -70.0, 'pressure': 877.0}
# {'id': '147', 'terrestrial_date': '2013-04-20', 'sol': 251, 'ls': 304.0, 'month': '11', 'min_temp': -71.0, 'pressure': 876.0}
# {'id': '148', 'terrestrial_date': '2013-04-22', 'sol': 252, 'ls': 304.0, 'month': '11', 'min_temp': -71.0, 'pressure': 874.0}
# {'id': '149', 'terrestrial_date': '2013-04-23', 'sol': 253, 'ls': 305.0, 'month': '11', 'min_temp': -71.0, 'pressure': 877.0}
# {'id': '150', 'terrestrial_date': '2013-04-24', 'sol': 254, 'ls': 306.0, 'month': '11', 'min_temp': -70.0, 'pressure': 871.0}
# {'id': '151', 'terrestrial_date': '2013-04-25', 'sol': 255, 'ls': 306.0, 'month': '11', 'min_temp': -69.0, 'pressure': 877.0}
# {'id': '152', 'terrestrial_date': '2013-04-26', 'sol': 256, 'ls': 307.0, 'month': '11', 'min_temp': -70.0, 'pressure': 871.0}
# {'id': '153', 'terrestrial_date': '2013-04-27', 'sol': 257, 'ls': 308.0, 'month': '11', 'min_temp': -70.0, 'pressure': 871.0}
# {'id': '154', 'terrestrial_date': '2013-04-28', 'sol': 258, 'ls': 308.0, 'month': '11', 'min_temp': -71.0, 'pressure': 869.0}
# {'id': '155', 'terrestrial_date': '2013-04-29', 'sol': 259, 'ls': 309.0, 'month': '11', 'min_temp': -72.0, 'pressure': 871.0}
# {'id': '157', 'terrestrial_date': '2013-04-30', 'sol': 260, 'ls': 309.0, 'month': '11', 'min_temp': -70.0, 'pressure': 875.0}
# {'id': '158', 'terrestrial_date': '2013-05-01', 'sol': 261, 'ls': 310.0, 'month': '11', 'min_temp': -70.0, 'pressure': 868.0}
# {'id': '161', 'terrestrial_date': '2013-05-08', 'sol': 268, 'ls': 314.0, 'month': '11', 'min_temp': -70.0, 'pressure': 864.0}
# {'id': '162', 'terrestrial_date': '2013-05-09', 'sol': 269, 'ls': 315.0, 'month': '11', 'min_temp': -72.0, 'pressure': 866.0}
# {'id': '164', 'terrestrial_date': '2013-05-10', 'sol': 270, 'ls': 315.0, 'month': '11', 'min_temp': -67.0, 'pressure': 863.0}
# {'id': '165', 'terrestrial_date': '2013-05-11', 'sol': 271, 'ls': 316.0, 'month': '11', 'min_temp': -69.0, 'pressure': 864.0}
# {'id': '166', 'terrestrial_date': '2013-05-12', 'sol': 272, 'ls': 316.0, 'month': '11', 'min_temp': -71.0, 'pressure': 864.0}
# {'id': '167', 'terrestrial_date': '2013-05-13', 'sol': 273, 'ls': 317.0, 'month': '11', 'min_temp': -70.0, 'pressure': 861.0}
# {'id': '168', 'terrestrial_date': '2013-05-14', 'sol': 274, 'ls': 318.0, 'month': '11', 'min_temp': -70.0, 'pressure': 861.0}
# {'id': '169', 'terrestrial_date': '2013-05-15', 'sol': 275, 'ls': 318.0, 'month': '11', 'min_temp': -67.0, 'pressure': 860.0}
# {'id': '244', 'terrestrial_date': '2013-05-16', 'sol': 276, 'ls': 319.0, 'month': '11', 'min_temp': -69.0, 'pressure': 858.0}
# {'id': '245', 'terrestrial_date': '2013-05-17', 'sol': 277, 'ls': 319.0, 'month': '11', 'min_temp': -69.0, 'pressure': 857.0}
# {'id': '246', 'terrestrial_date': '2013-05-18', 'sol': 278, 'ls': 320.0, 'month': '11', 'min_temp': -67.0, 'pressure': 855.0}
# {'id': '247', 'terrestrial_date': '2013-05-19', 'sol': 279, 'ls': 321.0, 'month': '11', 'min_temp': -68.0, 'pressure': 856.0}
# {'id': '248', 'terrestrial_date': '2013-05-20', 'sol': 280, 'ls': 321.0, 'month': '11', 'min_temp': -69.0, 'pressure': 856.0}
# {'id': '249', 'terrestrial_date': '2013-05-21', 'sol': 281, 'ls': 322.0, 'month': '11', 'min_temp': -68.0, 'pressure': 855.0}
# {'id': '250', 'terrestrial_date': '2013-05-22', 'sol': 282, 'ls': 322.0, 'month': '11', 'min_temp': -72.0, 'pressure': 856.0}
# {'id': '251', 'terrestrial_date': '2013-05-23', 'sol': 283, 'ls': 323.0, 'month': '11', 'min_temp': -68.0, 'pressure': 854.0}
# {'id': '252', 'terrestrial_date': '2013-05-24', 'sol': 284, 'ls': 323.0, 'month': '11', 'min_temp': -71.0, 'pressure': 854.0}
# {'id': '253', 'terrestrial_date': '2013-05-25', 'sol': 285, 'ls': 324.0, 'month': '11', 'min_temp': -70.0, 'pressure': 852.0}
# {'id': '254', 'terrestrial_date': '2013-05-26', 'sol': 286, 'ls': 325.0, 'month': '11', 'min_temp': -71.0, 'pressure': 854.0}
# {'id': '255', 'terrestrial_date': '2013-05-27', 'sol': 287, 'ls': 325.0, 'month': '11', 'min_temp': -72.0, 'pressure': 856.0}
# {'id': '256', 'terrestrial_date': '2013-05-29', 'sol': 288, 'ls': 326.0, 'month': '11', 'min_temp': -69.0, 'pressure': 854.0}
# {'id': '257', 'terrestrial_date': '2013-05-30', 'sol': 289, 'ls': 326.0, 'month': '11', 'min_temp': -71.0, 'pressure': 854.0}
# {'id': '258', 'terrestrial_date': '2013-05-31', 'sol': 290, 'ls': 327.0, 'month': '11', 'min_temp': -71.0, 'pressure': 853.0}
# {'id': '259', 'terrestrial_date': '2013-06-01', 'sol': 291, 'ls': 327.0, 'month': '11', 'min_temp': -70.0, 'pressure': 853.0}
# {'id': '260', 'terrestrial_date': '2013-06-02', 'sol': 292, 'ls': 328.0, 'month': '11', 'min_temp': -71.0, 'pressure': 853.0}
# {'id': '261', 'terrestrial_date': '2013-06-03', 'sol': 293, 'ls': 329.0, 'month': '11', 'min_temp': -72.0, 'pressure': 850.0}
# {'id': '262', 'terrestrial_date': '2013-06-04', 'sol': 294, 'ls': 329.0, 'month': '11', 'min_temp': -72.0, 'pressure': 852.0}
# {'id': '263', 'terrestrial_date': '2013-06-05', 'sol': 295, 'ls': 330.0, 'month': '12', 'min_temp': -71.0, 'pressure': 853.0}
# {'id': '264', 'terrestrial_date': '2013-06-06', 'sol': 296, 'ls': 330.0, 'month': '12', 'min_temp': -71.0, 'pressure': 850.0}
# {'id': '265', 'terrestrial_date': '2013-06-07', 'sol': 297, 'ls': 331.0, 'month': '12', 'min_temp': -72.0, 'pressure': 849.0}
# {'id': '266', 'terrestrial_date': '2013-06-08', 'sol': 298, 'ls': 331.0, 'month': '12', 'min_temp': -72.0, 'pressure': 850.0}
# {'id': '267', 'terrestrial_date': '2013-06-09', 'sol': 299, 'ls': 332.0, 'month': '12', 'min_temp': -71.0, 'pressure': 849.0}
# {'id': '286', 'terrestrial_date': '2013-06-10', 'sol': 300, 'ls': 333.0, 'month': '12', 'min_temp': -72.0, 'pressure': 852.0}
# {'id': '276', 'terrestrial_date': '2013-06-11', 'sol': 301, 'ls': 333.0, 'month': '12', 'min_temp': -73.0, 'pressure': 852.0}
# {'id': '287', 'terrestrial_date': '2013-06-12', 'sol': 302, 'ls': 334.0, 'month': '12', 'min_temp': -71.0, 'pressure': 850.0}
# {'id': '283', 'terrestrial_date': '2013-06-13', 'sol': 303, 'ls': 334.0, 'month': '12', 'min_temp': -71.0, 'pressure': 849.0}
# {'id': '281', 'terrestrial_date': '2013-06-14', 'sol': 304, 'ls': 335.0, 'month': '12', 'min_temp': -70.0, 'pressure': 848.0}
# {'id': '275', 'terrestrial_date': '2013-06-15', 'sol': 305, 'ls': 335.0, 'month': '12', 'min_temp': -71.0, 'pressure': 847.0}
# {'id': '280', 'terrestrial_date': '2013-06-16', 'sol': 306, 'ls': 336.0, 'month': '12', 'min_temp': -71.0, 'pressure': 848.0}
# {'id': '279', 'terrestrial_date': '2013-06-17', 'sol': 307, 'ls': 336.0, 'month': '12', 'min_temp': -72.0, 'pressure': 851.0}
# {'id': '282', 'terrestrial_date': '2013-06-18', 'sol': 308, 'ls': 337.0, 'month': '12', 'min_temp': -73.0, 'pressure': 850.0}
# {'id': '284', 'terrestrial_date': '2013-06-19', 'sol': 309, 'ls': 338.0, 'month': '12', 'min_temp': -72.0, 'pressure': 848.0}
# {'id': '278', 'terrestrial_date': '2013-06-20', 'sol': 310, 'ls': 338.0, 'month': '12', 'min_temp': -71.0, 'pressure': 849.0}
# {'id': '277', 'terrestrial_date': '2013-06-21', 'sol': 311, 'ls': 339.0, 'month': '12', 'min_temp': -74.0, 'pressure': 846.0}
# {'id': '285', 'terrestrial_date': '2013-06-22', 'sol': 312, 'ls': 339.0, 'month': '12', 'min_temp': -71.0, 'pressure': 845.0}
# {'id': '274', 'terrestrial_date': '2013-06-23', 'sol': 313, 'ls': 340.0, 'month': '12', 'min_temp': -77.0, 'pressure': 849.0}
# {'id': '272', 'terrestrial_date': '2013-06-24', 'sol': 314, 'ls': 340.0, 'month': '12', 'min_temp': -73.0, 'pressure': 848.0}
# {'id': '273', 'terrestrial_date': '2013-06-25', 'sol': 315, 'ls': 341.0, 'month': '12', 'min_temp': -74.0, 'pressure': 850.0}
# {'id': '288', 'terrestrial_date': '2013-06-26', 'sol': 316, 'ls': 341.0, 'month': '12', 'min_temp': -74.0, 'pressure': 851.0}
# {'id': '268', 'terrestrial_date': '2013-06-27', 'sol': 317, 'ls': 342.0, 'month': '12', 'min_temp': -72.0, 'pressure': 849.0}
# {'id': '270', 'terrestrial_date': '2013-06-28', 'sol': 318, 'ls': 342.0, 'month': '12', 'min_temp': -74.0, 'pressure': 849.0}
# {'id': '271', 'terrestrial_date': '2013-06-29', 'sol': 319, 'ls': 343.0, 'month': '12', 'min_temp': -73.0, 'pressure': 847.0}
# {'id': '269', 'terrestrial_date': '2013-06-30', 'sol': 320, 'ls': 344.0, 'month': '12', 'min_temp': -74.0, 'pressure': 846.0}
# {'id': '289', 'terrestrial_date': '2013-07-01', 'sol': 321, 'ls': 344.0, 'month': '12', 'min_temp': -75.0, 'pressure': 847.0}
# {'id': '291', 'terrestrial_date': '2013-07-02', 'sol': 322, 'ls': 345.0, 'month': '12', 'min_temp': -74.0, 'pressure': 849.0}
# {'id': '290', 'terrestrial_date': '2013-07-03', 'sol': 323, 'ls': 345.0, 'month': '12', 'min_temp': -74.0, 'pressure': 847.0}
# {'id': '292', 'terrestrial_date': '2013-07-04', 'sol': 324, 'ls': 346.0, 'month': '12', 'min_temp': -75.0, 'pressure': 850.0}
# {'id': '294', 'terrestrial_date': '2013-07-06', 'sol': 325, 'ls': 346.0, 'month': '12', 'min_temp': -74.0, 'pressure': 847.0}
# {'id': '295', 'terrestrial_date': '2013-07-07', 'sol': 326, 'ls': 347.0, 'month': '12', 'min_temp': -72.0, 'pressure': 848.0}
# {'id': '296', 'terrestrial_date': '2013-07-08', 'sol': 327, 'ls': 347.0, 'month': '12', 'min_temp': -74.0, 'pressure': 848.0}
# {'id': '293', 'terrestrial_date': '2013-07-09', 'sol': 328, 'ls': 348.0, 'month': '12', 'min_temp': -75.0, 'pressure': 847.0}
# {'id': '298', 'terrestrial_date': '2013-07-10', 'sol': 329, 'ls': 348.0, 'month': '12', 'min_temp': -74.0, 'pressure': 847.0}
# {'id': '297', 'terrestrial_date': '2013-07-11', 'sol': 330, 'ls': 349.0, 'month': '12', 'min_temp': -75.0, 'pressure': 848.0}
# {'id': '303', 'terrestrial_date': '2013-07-12', 'sol': 331, 'ls': 349.0, 'month': '12', 'min_temp': -74.0, 'pressure': 848.0}
# {'id': '300', 'terrestrial_date': '2013-07-13', 'sol': 332, 'ls': 350.0, 'month': '12', 'min_temp': -76.0, 'pressure': 849.0}
# {'id': '299', 'terrestrial_date': '2013-07-14', 'sol': 333, 'ls': 350.0, 'month': '12', 'min_temp': -75.0, 'pressure': 849.0}
# {'id': '301', 'terrestrial_date': '2013-07-15', 'sol': 334, 'ls': 351.0, 'month': '12', 'min_temp': -74.0, 'pressure': 852.0}
# {'id': '302', 'terrestrial_date': '2013-07-16', 'sol': 335, 'ls': 352.0, 'month': '12', 'min_temp': -76.0, 'pressure': 852.0}
# {'id': '305', 'terrestrial_date': '2013-07-17', 'sol': 336, 'ls': 352.0, 'month': '12', 'min_temp': -76.0, 'pressure': 852.0}
# {'id': '304', 'terrestrial_date': '2013-07-18', 'sol': 337, 'ls': 353.0, 'month': '12', 'min_temp': -75.0, 'pressure': 853.0}
# {'id': '306', 'terrestrial_date': '2013-07-19', 'sol': 338, 'ls': 353.0, 'month': '12', 'min_temp': -78.0, 'pressure': 848.0}
# {'id': '308', 'terrestrial_date': '2013-07-20', 'sol': 339, 'ls': 354.0, 'month': '12', 'min_temp': -76.0, 'pressure': 849.0}
# {'id': '307', 'terrestrial_date': '2013-07-21', 'sol': 340, 'ls': 354.0, 'month': '12', 'min_temp': -76.0, 'pressure': 851.0}
# {'id': '310', 'terrestrial_date': '2013-07-22', 'sol': 341, 'ls': 355.0, 'month': '12', 'min_temp': -77.0, 'pressure': 852.0}
# {'id': '309', 'terrestrial_date': '2013-07-23', 'sol': 342, 'ls': 355.0, 'month': '12', 'min_temp': -76.0, 'pressure': 851.0}
# {'id': '311', 'terrestrial_date': '2013-07-24', 'sol': 343, 'ls': 356.0, 'month': '12', 'min_temp': -77.0, 'pressure': 850.0}
# {'id': '317', 'terrestrial_date': '2013-07-25', 'sol': 344, 'ls': 356.0, 'month': '12', 'min_temp': -77.0, 'pressure': 851.0}
# {'id': '312', 'terrestrial_date': '2013-07-26', 'sol': 345, 'ls': 357.0, 'month': '12', 'min_temp': -77.0, 'pressure': 853.0}
# {'id': '314', 'terrestrial_date': '2013-07-27', 'sol': 346, 'ls': 357.0, 'month': '12', 'min_temp': -76.0, 'pressure': 853.0}
# {'id': '313', 'terrestrial_date': '2013-07-28', 'sol': 347, 'ls': 358.0, 'month': '12', 'min_temp': -77.0, 'pressure': 851.0}
# {'id': '315', 'terrestrial_date': '2013-07-29', 'sol': 348, 'ls': 358.0, 'month': '12', 'min_temp': -74.0, 'pressure': 850.0}
# {'id': '316', 'terrestrial_date': '2013-07-30', 'sol': 349, 'ls': 359.0, 'month': '12', 'min_temp': -75.0, 'pressure': 852.0}
# {'id': '318', 'terrestrial_date': '2013-07-31', 'sol': 350, 'ls': 359.0, 'month': '12', 'min_temp': -76.0, 'pressure': 853.0}
# {'id': '320', 'terrestrial_date': '2013-08-01', 'sol': 351, 'ls': 0.0, 'month': '1', 'min_temp': -75.0, 'pressure': 853.0}
# {'id': '319', 'terrestrial_date': '2013-08-02', 'sol': 352, 'ls': 0.0, 'month': '1', 'min_temp': -77.0, 'pressure': 854.0}
# {'id': '323', 'terrestrial_date': '2013-08-03', 'sol': 353, 'ls': 1.0, 'month': '1', 'min_temp': -75.0, 'pressure': 855.0}
# {'id': '322', 'terrestrial_date': '2013-08-04', 'sol': 354, 'ls': 1.0, 'month': '1', 'min_temp': -75.0, 'pressure': 857.0}
# {'id': '321', 'terrestrial_date': '2013-08-05', 'sol': 355, 'ls': 2.0, 'month': '1', 'min_temp': -75.0, 'pressure': 857.0}
# {'id': '324', 'terrestrial_date': '2013-08-06', 'sol': 356, 'ls': 2.0, 'month': '1', 'min_temp': -77.0, 'pressure': 856.0}
# {'id': '325', 'terrestrial_date': '2013-08-07', 'sol': 357, 'ls': 3.0, 'month': '1', 'min_temp': -76.0, 'pressure': 857.0}
# {'id': '326', 'terrestrial_date': '2013-08-17', 'sol': 366, 'ls': 7.0, 'month': '1', 'min_temp': -76.0, 'pressure': 861.0}
# {'id': '328', 'terrestrial_date': '2013-08-18', 'sol': 367, 'ls': 8.0, 'month': '1', 'min_temp': -76.0, 'pressure': 862.0}
# {'id': '330', 'terrestrial_date': '2013-08-19', 'sol': 368, 'ls': 8.0, 'month': '1', 'min_temp': -77.0, 'pressure': 863.0}
# {'id': '331', 'terrestrial_date': '2013-08-20', 'sol': 369, 'ls': 9.0, 'month': '1', 'min_temp': -75.0, 'pressure': 865.0}
# {'id': '332', 'terrestrial_date': '2013-08-21', 'sol': 370, 'ls': 9.0, 'month': '1', 'min_temp': -79.0, 'pressure': 865.0}
# {'id': '333', 'terrestrial_date': '2013-08-22', 'sol': 371, 'ls': 10.0, 'month': '1', 'min_temp': -77.0, 'pressure': 865.0}
# {'id': '334', 'terrestrial_date': '2013-08-23', 'sol': 372, 'ls': 10.0, 'month': '1', 'min_temp': -76.0, 'pressure': 866.0}
# {'id': '335', 'terrestrial_date': '2013-08-24', 'sol': 373, 'ls': 11.0, 'month': '1', 'min_temp': -79.0, 'pressure': 866.0}
# {'id': '337', 'terrestrial_date': '2013-08-25', 'sol': 374, 'ls': 11.0, 'month': '1', 'min_temp': -79.0, 'pressure': 866.0}
# {'id': '336', 'terrestrial_date': '2013-08-26', 'sol': 375, 'ls': 12.0, 'month': '1', 'min_temp': -77.0, 'pressure': 867.0}
# {'id': '340', 'terrestrial_date': '2013-08-27', 'sol': 376, 'ls': 12.0, 'month': '1', 'min_temp': -78.0, 'pressure': 870.0}
# {'id': '338', 'terrestrial_date': '2013-08-28', 'sol': 377, 'ls': 13.0, 'month': '1', 'min_temp': -78.0, 'pressure': 870.0}
# {'id': '339', 'terrestrial_date': '2013-08-29', 'sol': 378, 'ls': 13.0, 'month': '1', 'min_temp': -78.0, 'pressure': 869.0}
# {'id': '341', 'terrestrial_date': '2013-08-30', 'sol': 379, 'ls': 14.0, 'month': '1', 'min_temp': -79.0, 'pressure': 870.0}
# {'id': '343', 'terrestrial_date': '2013-08-31', 'sol': 380, 'ls': 14.0, 'month': '1', 'min_temp': -79.0, 'pressure': 870.0}
# {'id': '345', 'terrestrial_date': '2013-09-01', 'sol': 381, 'ls': 15.0, 'month': '1', 'min_temp': -79.0, 'pressure': 871.0}
# {'id': '344', 'terrestrial_date': '2013-09-02', 'sol': 382, 'ls': 15.0, 'month': '1', 'min_temp': -76.0, 'pressure': 872.0}
# {'id': '342', 'terrestrial_date': '2013-09-03', 'sol': 383, 'ls': 16.0, 'month': '1', 'min_temp': -77.0, 'pressure': 874.0}
# {'id': '346', 'terrestrial_date': '2013-09-04', 'sol': 384, 'ls': 16.0, 'month': '1', 'min_temp': -77.0, 'pressure': 875.0}
# {'id': '351', 'terrestrial_date': '2013-09-05', 'sol': 385, 'ls': 17.0, 'month': '1', 'min_temp': -78.0, 'pressure': 874.0}
# {'id': '347', 'terrestrial_date': '2013-09-06', 'sol': 386, 'ls': 17.0, 'month': '1', 'min_temp': -77.0, 'pressure': 873.0}
# {'id': '349', 'terrestrial_date': '2013-09-07', 'sol': 387, 'ls': 18.0, 'month': '1', 'min_temp': -78.0, 'pressure': 874.0}
# {'id': '350', 'terrestrial_date': '2013-09-08', 'sol': 388, 'ls': 18.0, 'month': '1', 'min_temp': -79.0, 'pressure': 875.0}
# {'id': '348', 'terrestrial_date': '2013-09-09', 'sol': 389, 'ls': 19.0, 'month': '1', 'min_temp': -79.0, 'pressure': 875.0}
# {'id': '352', 'terrestrial_date': '2013-09-10', 'sol': 390, 'ls': 19.0, 'month': '1', 'min_temp': -78.0, 'pressure': 875.0}
# {'id': '353', 'terrestrial_date': '2013-09-11', 'sol': 391, 'ls': 20.0, 'month': '1', 'min_temp': -78.0, 'pressure': 875.0}
# {'id': '354', 'terrestrial_date': '2013-09-12', 'sol': 392, 'ls': 20.0, 'month': '1', 'min_temp': -77.0, 'pressure': 876.0}
# {'id': '355', 'terrestrial_date': '2013-09-13', 'sol': 393, 'ls': 21.0, 'month': '1', 'min_temp': -76.0, 'pressure': 877.0}
# {'id': '356', 'terrestrial_date': '2013-09-14', 'sol': 394, 'ls': 21.0, 'month': '1', 'min_temp': -79.0, 'pressure': 878.0}
# {'id': '357', 'terrestrial_date': '2013-09-15', 'sol': 395, 'ls': 22.0, 'month': '1', 'min_temp': -77.0, 'pressure': 878.0}
# {'id': '358', 'terrestrial_date': '2013-09-16', 'sol': 396, 'ls': 22.0, 'month': '1', 'min_temp': -78.0, 'pressure': 879.0}
# {'id': '359', 'terrestrial_date': '2013-09-18', 'sol': 397, 'ls': 23.0, 'month': '1', 'min_temp': -75.0, 'pressure': 880.0}
# {'id': '360', 'terrestrial_date': '2013-09-19', 'sol': 398, 'ls': 23.0, 'month': '1', 'min_temp': -79.0, 'pressure': 880.0}
# {'id': '361', 'terrestrial_date': '2013-09-20', 'sol': 399, 'ls': 24.0, 'month': '1', 'min_temp': -79.0, 'pressure': 881.0}
# {'id': '363', 'terrestrial_date': '2013-09-21', 'sol': 400, 'ls': 24.0, 'month': '1', 'min_temp': -79.0, 'pressure': 881.0}
# {'id': '362', 'terrestrial_date': '2013-09-22', 'sol': 401, 'ls': 25.0, 'month': '1', 'min_temp': -79.0, 'pressure': 882.0}
# {'id': '365', 'terrestrial_date': '2013-09-23', 'sol': 402, 'ls': 25.0, 'month': '1', 'min_temp': -78.0, 'pressure': 883.0}
# {'id': '364', 'terrestrial_date': '2013-09-24', 'sol': 403, 'ls': 25.0, 'month': '1', 'min_temp': -80.0, 'pressure': 883.0}
# {'id': '367', 'terrestrial_date': '2013-09-25', 'sol': 404, 'ls': 26.0, 'month': '1', 'min_temp': -78.0, 'pressure': 884.0}
# {'id': '366', 'terrestrial_date': '2013-09-26', 'sol': 405, 'ls': 26.0, 'month': '1', 'min_temp': -82.0, 'pressure': 885.0}
# {'id': '374', 'terrestrial_date': '2013-09-27', 'sol': 406, 'ls': 27.0, 'month': '1', 'min_temp': -81.0, 'pressure': 886.0}
# {'id': '370', 'terrestrial_date': '2013-09-28', 'sol': 407, 'ls': 27.0, 'month': '1', 'min_temp': -81.0, 'pressure': 887.0}
# {'id': '369', 'terrestrial_date': '2013-09-29', 'sol': 408, 'ls': 28.0, 'month': '1', 'min_temp': -80.0, 'pressure': 887.0}
# {'id': '368', 'terrestrial_date': '2013-09-30', 'sol': 409, 'ls': 28.0, 'month': '1', 'min_temp': -81.0, 'pressure': 887.0}
# {'id': '373', 'terrestrial_date': '2013-10-01', 'sol': 410, 'ls': 29.0, 'month': '1', 'min_temp': -81.0, 'pressure': 888.0}
# {'id': '372', 'terrestrial_date': '2013-10-02', 'sol': 411, 'ls': 29.0, 'month': '1', 'min_temp': -82.0, 'pressure': 887.0}
# {'id': '371', 'terrestrial_date': '2013-10-03', 'sol': 412, 'ls': 30.0, 'month': '2', 'min_temp': -80.0, 'pressure': 888.0}
# {'id': '376', 'terrestrial_date': '2013-10-04', 'sol': 413, 'ls': 30.0, 'month': '2', 'min_temp': -82.0, 'pressure': 888.0}
# {'id': '375', 'terrestrial_date': '2013-10-05', 'sol': 414, 'ls': 31.0, 'month': '2', 'min_temp': -79.0, 'pressure': 889.0}
# {'id': '377', 'terrestrial_date': '2013-10-06', 'sol': 415, 'ls': 31.0, 'month': '2', 'min_temp': -82.0, 'pressure': 890.0}
# {'id': '378', 'terrestrial_date': '2013-10-07', 'sol': 416, 'ls': 32.0, 'month': '2', 'min_temp': -79.0, 'pressure': 889.0}
# {'id': '379', 'terrestrial_date': '2013-10-08', 'sol': 417, 'ls': 32.0, 'month': '2', 'min_temp': -82.0, 'pressure': 890.0}
# {'id': '380', 'terrestrial_date': '2013-10-09', 'sol': 418, 'ls': 33.0, 'month': '2', 'min_temp': -79.0, 'pressure': 891.0}
# {'id': '381', 'terrestrial_date': '2013-10-10', 'sol': 419, 'ls': 33.0, 'month': '2', 'min_temp': -82.0, 'pressure': 891.0}
# {'id': '385', 'terrestrial_date': '2013-10-11', 'sol': 420, 'ls': 33.0, 'month': '2', 'min_temp': -80.0, 'pressure': 892.0}
# {'id': '382', 'terrestrial_date': '2013-10-12', 'sol': 421, 'ls': 34.0, 'month': '2', 'min_temp': -81.0, 'pressure': 890.0}
# {'id': '384', 'terrestrial_date': '2013-10-13', 'sol': 422, 'ls': 34.0, 'month': '2', 'min_temp': -82.0, 'pressure': 891.0}
# {'id': '383', 'terrestrial_date': '2013-10-14', 'sol': 423, 'ls': 35.0, 'month': '2', 'min_temp': -81.0, 'pressure': 892.0}
# {'id': '386', 'terrestrial_date': '2013-10-15', 'sol': 424, 'ls': 35.0, 'month': '2', 'min_temp': -81.0, 'pressure': 893.0}
# {'id': '393', 'terrestrial_date': '2013-10-16', 'sol': 425, 'ls': 36.0, 'month': '2', 'min_temp': -81.0, 'pressure': 893.0}
# {'id': '388', 'terrestrial_date': '2013-10-17', 'sol': 426, 'ls': 36.0, 'month': '2', 'min_temp': -79.0, 'pressure': 893.0}
# {'id': '392', 'terrestrial_date': '2013-10-18', 'sol': 427, 'ls': 37.0, 'month': '2', 'min_temp': -81.0, 'pressure': 893.0}
# {'id': '391', 'terrestrial_date': '2013-10-19', 'sol': 428, 'ls': 37.0, 'month': '2', 'min_temp': -81.0, 'pressure': 894.0}
# {'id': '387', 'terrestrial_date': '2013-10-20', 'sol': 429, 'ls': 38.0, 'month': '2', 'min_temp': -82.0, 'pressure': 895.0}
# {'id': '390', 'terrestrial_date': '2013-10-21', 'sol': 430, 'ls': 38.0, 'month': '2', 'min_temp': -82.0, 'pressure': 896.0}
# {'id': '389', 'terrestrial_date': '2013-10-22', 'sol': 431, 'ls': 39.0, 'month': '2', 'min_temp': -83.0, 'pressure': 895.0}
# {'id': '395', 'terrestrial_date': '2013-10-23', 'sol': 432, 'ls': 39.0, 'month': '2', 'min_temp': -80.0, 'pressure': 896.0}
# {'id': '394', 'terrestrial_date': '2013-10-24', 'sol': 433, 'ls': 40.0, 'month': '2', 'min_temp': -81.0, 'pressure': 895.0}
# {'id': '397', 'terrestrial_date': '2013-10-26', 'sol': 434, 'ls': 40.0, 'month': '2', 'min_temp': -80.0, 'pressure': 896.0}
# {'id': '396', 'terrestrial_date': '2013-10-27', 'sol': 435, 'ls': 40.0, 'month': '2', 'min_temp': -81.0, 'pressure': 896.0}
# {'id': '398', 'terrestrial_date': '2013-10-28', 'sol': 436, 'ls': 41.0, 'month': '2', 'min_temp': -81.0, 'pressure': 897.0}
# {'id': '399', 'terrestrial_date': '2013-10-29', 'sol': 437, 'ls': 41.0, 'month': '2', 'min_temp': -82.0, 'pressure': 898.0}
# {'id': '400', 'terrestrial_date': '2013-10-30', 'sol': 438, 'ls': 42.0, 'month': '2', 'min_temp': -79.0, 'pressure': 899.0}
# {'id': '401', 'terrestrial_date': '2013-10-31', 'sol': 439, 'ls': 42.0, 'month': '2', 'min_temp': -80.0, 'pressure': 899.0}
# ...
# {'id': '1769', 'terrestrial_date': '2017-10-22', 'sol': 1852, 'ls': 77.0, 'month': '3', 'min_temp': -80.0, 'pressure': 863.0}
# {'id': '1771', 'terrestrial_date': '2017-10-23', 'sol': 1853, 'ls': 77.0, 'month': '3', 'min_temp': -80.0, 'pressure': 862.0}
# {'id': '1772', 'terrestrial_date': '2017-10-24', 'sol': 1854, 'ls': 77.0, 'month': '3', 'min_temp': -80.0, 'pressure': 861.0}
# {'id': '1773', 'terrestrial_date': '2017-10-25', 'sol': 1855, 'ls': 78.0, 'month': '3', 'min_temp': -78.0, 'pressure': 861.0}
# {'id': '1774', 'terrestrial_date': '2017-10-26', 'sol': 1856, 'ls': 78.0, 'month': '3', 'min_temp': -80.0, 'pressure': 859.0}
# {'id': '1776', 'terrestrial_date': '2017-10-27', 'sol': 1857, 'ls': 79.0, 'month': '3', 'min_temp': -80.0, 'pressure': 858.0}
# {'id': '1775', 'terrestrial_date': '2017-10-28', 'sol': 1858, 'ls': 79.0, 'month': '3', 'min_temp': -81.0, 'pressure': 857.0}
# {'id': '1779', 'terrestrial_date': '2017-10-29', 'sol': 1859, 'ls': 80.0, 'month': '3', 'min_temp': -79.0, 'pressure': 857.0}
# {'id': '1778', 'terrestrial_date': '2017-10-30', 'sol': 1860, 'ls': 80.0, 'month': '3', 'min_temp': -80.0, 'pressure': 857.0}
# {'id': '1780', 'terrestrial_date': '2017-10-31', 'sol': 1861, 'ls': 81.0, 'month': '3', 'min_temp': -79.0, 'pressure': 855.0}
# {'id': '1777', 'terrestrial_date': '2017-11-01', 'sol': 1862, 'ls': 81.0, 'month': '3', 'min_temp': -81.0, 'pressure': 854.0}
# {'id': '1781', 'terrestrial_date': '2017-11-02', 'sol': 1863, 'ls': 81.0, 'month': '3', 'min_temp': -80.0, 'pressure': 853.0}
# {'id': '1782', 'terrestrial_date': '2017-11-03', 'sol': 1864, 'ls': 82.0, 'month': '3', 'min_temp': -82.0, 'pressure': 852.0}
# {'id': '1783', 'terrestrial_date': '2017-11-04', 'sol': 1865, 'ls': 82.0, 'month': '3', 'min_temp': -80.0, 'pressure': 852.0}
# {'id': '1785', 'terrestrial_date': '2017-11-05', 'sol': 1866, 'ls': 83.0, 'month': '3', 'min_temp': -80.0, 'pressure': 850.0}
# {'id': '1784', 'terrestrial_date': '2017-11-06', 'sol': 1867, 'ls': 83.0, 'month': '3', 'min_temp': -78.0, 'pressure': 848.0}
# {'id': '1786', 'terrestrial_date': '2017-11-07', 'sol': 1868, 'ls': 84.0, 'month': '3', 'min_temp': -80.0, 'pressure': 848.0}
# {'id': '1787', 'terrestrial_date': '2017-11-08', 'sol': 1869, 'ls': 84.0, 'month': '3', 'min_temp': -81.0, 'pressure': 846.0}
# {'id': '1788', 'terrestrial_date': '2017-11-09', 'sol': 1870, 'ls': 85.0, 'month': '3', 'min_temp': -81.0, 'pressure': 845.0}
# {'id': '1789', 'terrestrial_date': '2017-11-10', 'sol': 1871, 'ls': 85.0, 'month': '3', 'min_temp': -80.0, 'pressure': 844.0}
# {'id': '1791', 'terrestrial_date': '2017-11-11', 'sol': 1872, 'ls': 86.0, 'month': '3', 'min_temp': -79.0, 'pressure': 843.0}
# {'id': '1790', 'terrestrial_date': '2017-11-12', 'sol': 1873, 'ls': 86.0, 'month': '3', 'min_temp': -79.0, 'pressure': 842.0}
# {'id': '1792', 'terrestrial_date': '2017-11-13', 'sol': 1874, 'ls': 86.0, 'month': '3', 'min_temp': -80.0, 'pressure': 840.0}
# {'id': '1793', 'terrestrial_date': '2017-11-14', 'sol': 1875, 'ls': 87.0, 'month': '3', 'min_temp': -79.0, 'pressure': 839.0}
# {'id': '1794', 'terrestrial_date': '2017-11-15', 'sol': 1876, 'ls': 87.0, 'month': '3', 'min_temp': -79.0, 'pressure': 838.0}
# {'id': '1797', 'terrestrial_date': '2017-11-16', 'sol': 1877, 'ls': 88.0, 'month': '3', 'min_temp': -79.0, 'pressure': 837.0}
# {'id': '1795', 'terrestrial_date': '2017-11-17', 'sol': 1878, 'ls': 88.0, 'month': '3', 'min_temp': -79.0, 'pressure': 835.0}
# {'id': '1796', 'terrestrial_date': '2017-11-18', 'sol': 1879, 'ls': 89.0, 'month': '3', 'min_temp': -79.0, 'pressure': 834.0}
# {'id': '1798', 'terrestrial_date': '2017-11-19', 'sol': 1880, 'ls': 89.0, 'month': '3', 'min_temp': -79.0, 'pressure': 833.0}
# {'id': '1803', 'terrestrial_date': '2017-11-20', 'sol': 1881, 'ls': 90.0, 'month': '4', 'min_temp': -79.0, 'pressure': 832.0}
# {'id': '1801', 'terrestrial_date': '2017-11-21', 'sol': 1882, 'ls': 90.0, 'month': '4', 'min_temp': -78.0, 'pressure': 831.0}
# {'id': '1800', 'terrestrial_date': '2017-11-22', 'sol': 1883, 'ls': 91.0, 'month': '4', 'min_temp': -78.0, 'pressure': 830.0}
# {'id': '1799', 'terrestrial_date': '2017-11-23', 'sol': 1884, 'ls': 91.0, 'month': '4', 'min_temp': -79.0, 'pressure': 829.0}
# {'id': '1804', 'terrestrial_date': '2017-11-24', 'sol': 1885, 'ls': 91.0, 'month': '4', 'min_temp': -79.0, 'pressure': 827.0}
# {'id': '1805', 'terrestrial_date': '2017-11-25', 'sol': 1886, 'ls': 92.0, 'month': '4', 'min_temp': -79.0, 'pressure': 826.0}
# {'id': '1802', 'terrestrial_date': '2017-11-26', 'sol': 1887, 'ls': 92.0, 'month': '4', 'min_temp': -79.0, 'pressure': 824.0}
# {'id': '1807', 'terrestrial_date': '2017-11-27', 'sol': 1888, 'ls': 93.0, 'month': '4', 'min_temp': -79.0, 'pressure': 823.0}
# {'id': '1806', 'terrestrial_date': '2017-11-29', 'sol': 1889, 'ls': 93.0, 'month': '4', 'min_temp': -80.0, 'pressure': 822.0}
# {'id': '1808', 'terrestrial_date': '2017-11-30', 'sol': 1890, 'ls': 94.0, 'month': '4', 'min_temp': -79.0, 'pressure': 821.0}
# {'id': '1810', 'terrestrial_date': '2017-12-01', 'sol': 1891, 'ls': 94.0, 'month': '4', 'min_temp': -80.0, 'pressure': 819.0}
# {'id': '1809', 'terrestrial_date': '2017-12-02', 'sol': 1892, 'ls': 95.0, 'month': '4', 'min_temp': -81.0, 'pressure': 817.0}
# {'id': '1812', 'terrestrial_date': '2017-12-03', 'sol': 1893, 'ls': 95.0, 'month': '4', 'min_temp': -79.0, 'pressure': 816.0}
# {'id': '1811', 'terrestrial_date': '2017-12-04', 'sol': 1894, 'ls': 96.0, 'month': '4', 'min_temp': -79.0, 'pressure': 815.0}
# {'id': '1814', 'terrestrial_date': '2017-12-05', 'sol': 1895, 'ls': 96.0, 'month': '4', 'min_temp': -78.0, 'pressure': 814.0}
# {'id': '1813', 'terrestrial_date': '2017-12-06', 'sol': 1896, 'ls': 96.0, 'month': '4', 'min_temp': -79.0, 'pressure': 812.0}
# {'id': '1817', 'terrestrial_date': '2017-12-07', 'sol': 1897, 'ls': 97.0, 'month': '4', 'min_temp': -80.0, 'pressure': 811.0}
# {'id': '1816', 'terrestrial_date': '2017-12-08', 'sol': 1898, 'ls': 97.0, 'month': '4', 'min_temp': -81.0, 'pressure': 810.0}
# {'id': '1815', 'terrestrial_date': '2017-12-09', 'sol': 1899, 'ls': 98.0, 'month': '4', 'min_temp': -81.0, 'pressure': 808.0}
# {'id': '1818', 'terrestrial_date': '2017-12-10', 'sol': 1900, 'ls': 98.0, 'month': '4', 'min_temp': -81.0, 'pressure': 807.0}
# {'id': '1819', 'terrestrial_date': '2017-12-11', 'sol': 1901, 'ls': 99.0, 'month': '4', 'min_temp': -81.0, 'pressure': 806.0}
# {'id': '1820', 'terrestrial_date': '2017-12-12', 'sol': 1902, 'ls': 99.0, 'month': '4', 'min_temp': -79.0, 'pressure': 804.0}
# {'id': '1821', 'terrestrial_date': '2017-12-13', 'sol': 1903, 'ls': 100.0, 'month': '4', 'min_temp': -78.0, 'pressure': 803.0}
# {'id': '1822', 'terrestrial_date': '2017-12-14', 'sol': 1904, 'ls': 100.0, 'month': '4', 'min_temp': -79.0, 'pressure': 801.0}
# {'id': '1823', 'terrestrial_date': '2017-12-15', 'sol': 1905, 'ls': 101.0, 'month': '4', 'min_temp': -80.0, 'pressure': 800.0}
# {'id': '1824', 'terrestrial_date': '2017-12-16', 'sol': 1906, 'ls': 101.0, 'month': '4', 'min_temp': -79.0, 'pressure': 799.0}
# {'id': '1825', 'terrestrial_date': '2017-12-17', 'sol': 1907, 'ls': 101.0, 'month': '4', 'min_temp': -79.0, 'pressure': 798.0}
# {'id': '1826', 'terrestrial_date': '2017-12-18', 'sol': 1908, 'ls': 102.0, 'month': '4', 'min_temp': -79.0, 'pressure': 796.0}
# {'id': '1827', 'terrestrial_date': '2017-12-19', 'sol': 1909, 'ls': 102.0, 'month': '4', 'min_temp': -80.0, 'pressure': 795.0}
# {'id': '1828', 'terrestrial_date': '2017-12-20', 'sol': 1910, 'ls': 103.0, 'month': '4', 'min_temp': -80.0, 'pressure': 794.0}
# {'id': '1833', 'terrestrial_date': '2017-12-21', 'sol': 1911, 'ls': 103.0, 'month': '4', 'min_temp': -79.0, 'pressure': 792.0}
# {'id': '1832', 'terrestrial_date': '2017-12-22', 'sol': 1912, 'ls': 104.0, 'month': '4', 'min_temp': -80.0, 'pressure': 791.0}
# {'id': '1830', 'terrestrial_date': '2017-12-23', 'sol': 1913, 'ls': 104.0, 'month': '4', 'min_temp': -79.0, 'pressure': 791.0}
# {'id': '1834', 'terrestrial_date': '2017-12-24', 'sol': 1914, 'ls': 105.0, 'month': '4', 'min_temp': -78.0, 'pressure': 790.0}
# {'id': '1835', 'terrestrial_date': '2017-12-25', 'sol': 1915, 'ls': 105.0, 'month': '4', 'min_temp': -78.0, 'pressure': 788.0}
# {'id': '1829', 'terrestrial_date': '2017-12-26', 'sol': 1916, 'ls': 106.0, 'month': '4', 'min_temp': -79.0, 'pressure': 787.0}
# {'id': '1831', 'terrestrial_date': '2017-12-27', 'sol': 1917, 'ls': 106.0, 'month': '4', 'min_temp': -80.0, 'pressure': 786.0}
# {'id': '1839', 'terrestrial_date': '2017-12-28', 'sol': 1918, 'ls': 107.0, 'month': '4', 'min_temp': -77.0, 'pressure': 784.0}
# {'id': '1836', 'terrestrial_date': '2017-12-29', 'sol': 1919, 'ls': 107.0, 'month': '4', 'min_temp': -77.0, 'pressure': 783.0}
# {'id': '1837', 'terrestrial_date': '2017-12-30', 'sol': 1920, 'ls': 108.0, 'month': '4', 'min_temp': -77.0, 'pressure': 782.0}
# {'id': '1838', 'terrestrial_date': '2017-12-31', 'sol': 1921, 'ls': 108.0, 'month': '4', 'min_temp': -78.0, 'pressure': 781.0}
# {'id': '1840', 'terrestrial_date': '2018-01-01', 'sol': 1922, 'ls': 108.0, 'month': '4', 'min_temp': -79.0, 'pressure': 780.0}
# {'id': '1842', 'terrestrial_date': '2018-01-02', 'sol': 1923, 'ls': 109.0, 'month': '4', 'min_temp': -77.0, 'pressure': 778.0}
# {'id': '1841', 'terrestrial_date': '2018-01-03', 'sol': 1924, 'ls': 109.0, 'month': '4', 'min_temp': -78.0, 'pressure': 777.0}
# {'id': '1844', 'terrestrial_date': '2018-01-05', 'sol': 1925, 'ls': 110.0, 'month': '4', 'min_temp': -79.0, 'pressure': 777.0}
# {'id': '1843', 'terrestrial_date': '2018-01-06', 'sol': 1926, 'ls': 110.0, 'month': '4', 'min_temp': -80.0, 'pressure': 775.0}
# {'id': '1845', 'terrestrial_date': '2018-01-07', 'sol': 1927, 'ls': 111.0, 'month': '4', 'min_temp': -79.0, 'pressure': 774.0}
# {'id': '1847', 'terrestrial_date': '2018-01-08', 'sol': 1928, 'ls': 111.0, 'month': '4', 'min_temp': -78.0, 'pressure': 773.0}
# {'id': '1846', 'terrestrial_date': '2018-01-09', 'sol': 1929, 'ls': 112.0, 'month': '4', 'min_temp': -79.0, 'pressure': 771.0}
# {'id': '1848', 'terrestrial_date': '2018-01-10', 'sol': 1930, 'ls': 112.0, 'month': '4', 'min_temp': -79.0, 'pressure': 770.0}
# {'id': '1849', 'terrestrial_date': '2018-01-11', 'sol': 1931, 'ls': 113.0, 'month': '4', 'min_temp': -79.0, 'pressure': 770.0}
# {'id': '1850', 'terrestrial_date': '2018-01-12', 'sol': 1932, 'ls': 113.0, 'month': '4', 'min_temp': -79.0, 'pressure': 768.0}
# {'id': '1852', 'terrestrial_date': '2018-01-13', 'sol': 1933, 'ls': 114.0, 'month': '4', 'min_temp': -78.0, 'pressure': 767.0}
# {'id': '1851', 'terrestrial_date': '2018-01-14', 'sol': 1934, 'ls': 114.0, 'month': '4', 'min_temp': -79.0, 'pressure': 766.0}
# {'id': '1853', 'terrestrial_date': '2018-01-15', 'sol': 1935, 'ls': 115.0, 'month': '4', 'min_temp': -80.0, 'pressure': 765.0}
# {'id': '1855', 'terrestrial_date': '2018-01-16', 'sol': 1936, 'ls': 115.0, 'month': '4', 'min_temp': -79.0, 'pressure': 764.0}
# {'id': '1854', 'terrestrial_date': '2018-01-17', 'sol': 1937, 'ls': 116.0, 'month': '4', 'min_temp': -80.0, 'pressure': 763.0}
# {'id': '1859', 'terrestrial_date': '2018-01-18', 'sol': 1938, 'ls': 116.0, 'month': '4', 'min_temp': -78.0, 'pressure': 762.0}
# {'id': '1857', 'terrestrial_date': '2018-01-19', 'sol': 1939, 'ls': 116.0, 'month': '4', 'min_temp': -78.0, 'pressure': 760.0}
# {'id': '1858', 'terrestrial_date': '2018-01-20', 'sol': 1940, 'ls': 117.0, 'month': '4', 'min_temp': -77.0, 'pressure': 759.0}
# {'id': '1856', 'terrestrial_date': '2018-01-21', 'sol': 1941, 'ls': 117.0, 'month': '4', 'min_temp': -77.0, 'pressure': 758.0}
# {'id': '1860', 'terrestrial_date': '2018-01-22', 'sol': 1942, 'ls': 118.0, 'month': '4', 'min_temp': -78.0, 'pressure': 757.0}
# {'id': '1863', 'terrestrial_date': '2018-01-23', 'sol': 1943, 'ls': 118.0, 'month': '4', 'min_temp': -78.0, 'pressure': 756.0}
# {'id': '1861', 'terrestrial_date': '2018-01-24', 'sol': 1944, 'ls': 119.0, 'month': '4', 'min_temp': -80.0, 'pressure': 755.0}
# {'id': '1862', 'terrestrial_date': '2018-01-25', 'sol': 1945, 'ls': 119.0, 'month': '4', 'min_temp': -78.0, 'pressure': 754.0}
# {'id': '1864', 'terrestrial_date': '2018-01-26', 'sol': 1946, 'ls': 120.0, 'month': '5', 'min_temp': -79.0, 'pressure': 753.0}
# {'id': '1865', 'terrestrial_date': '2018-01-27', 'sol': 1947, 'ls': 120.0, 'month': '5', 'min_temp': -78.0, 'pressure': 751.0}
# {'id': '1866', 'terrestrial_date': '2018-01-28', 'sol': 1948, 'ls': 121.0, 'month': '5', 'min_temp': -78.0, 'pressure': 752.0}
# {'id': '1867', 'terrestrial_date': '2018-01-29', 'sol': 1949, 'ls': 121.0, 'month': '5', 'min_temp': -78.0, 'pressure': 751.0}
# {'id': '1868', 'terrestrial_date': '2018-01-30', 'sol': 1950, 'ls': 122.0, 'month': '5', 'min_temp': -79.0, 'pressure': 750.0}
# {'id': '1869', 'terrestrial_date': '2018-01-31', 'sol': 1951, 'ls': 122.0, 'month': '5', 'min_temp': -77.0, 'pressure': 749.0}
# {'id': '1871', 'terrestrial_date': '2018-02-01', 'sol': 1952, 'ls': 123.0, 'month': '5', 'min_temp': -80.0, 'pressure': 748.0}
# {'id': '1870', 'terrestrial_date': '2018-02-02', 'sol': 1953, 'ls': 123.0, 'month': '5', 'min_temp': -78.0, 'pressure': 747.0}
# {'id': '1872', 'terrestrial_date': '2018-02-03', 'sol': 1954, 'ls': 124.0, 'month': '5', 'min_temp': -77.0, 'pressure': 745.0}
# {'id': '1873', 'terrestrial_date': '2018-02-04', 'sol': 1955, 'ls': 124.0, 'month': '5', 'min_temp': -77.0, 'pressure': 745.0}
# {'id': '1879', 'terrestrial_date': '2018-02-05', 'sol': 1956, 'ls': 125.0, 'month': '5', 'min_temp': -79.0, 'pressure': 744.0}
# {'id': '1875', 'terrestrial_date': '2018-02-06', 'sol': 1957, 'ls': 125.0, 'month': '5', 'min_temp': -77.0, 'pressure': 742.0}
# {'id': '1874', 'terrestrial_date': '2018-02-07', 'sol': 1958, 'ls': 126.0, 'month': '5', 'min_temp': -77.0, 'pressure': 741.0}
# {'id': '1878', 'terrestrial_date': '2018-02-08', 'sol': 1959, 'ls': 126.0, 'month': '5', 'min_temp': -78.0, 'pressure': 740.0}
# {'id': '1876', 'terrestrial_date': '2018-02-09', 'sol': 1960, 'ls': 127.0, 'month': '5', 'min_temp': -78.0, 'pressure': 740.0}
# {'id': '1877', 'terrestrial_date': '2018-02-11', 'sol': 1961, 'ls': 127.0, 'month': '5', 'min_temp': -77.0, 'pressure': 740.0}
# {'id': '1880', 'terrestrial_date': '2018-02-12', 'sol': 1962, 'ls': 128.0, 'month': '5', 'min_temp': -78.0, 'pressure': 738.0}
# {'id': '1881', 'terrestrial_date': '2018-02-13', 'sol': 1963, 'ls': 128.0, 'month': '5', 'min_temp': -77.0, 'pressure': 737.0}
# {'id': '1882', 'terrestrial_date': '2018-02-14', 'sol': 1964, 'ls': 129.0, 'month': '5', 'min_temp': -76.0, 'pressure': 736.0}
# {'id': '1883', 'terrestrial_date': '2018-02-15', 'sol': 1965, 'ls': 129.0, 'month': '5', 'min_temp': -76.0, 'pressure': 735.0}
# {'id': '1884', 'terrestrial_date': '2018-02-16', 'sol': 1966, 'ls': 130.0, 'month': '5', 'min_temp': -77.0, 'pressure': 735.0}
# {'id': '1885', 'terrestrial_date': '2018-02-17', 'sol': 1967, 'ls': 130.0, 'month': '5', 'min_temp': -76.0, 'pressure': 734.0}
# {'id': '1886', 'terrestrial_date': '2018-02-18', 'sol': 1968, 'ls': 131.0, 'month': '5', 'min_temp': -76.0, 'pressure': 732.0}
# {'id': '1887', 'terrestrial_date': '2018-02-19', 'sol': 1969, 'ls': 131.0, 'month': '5', 'min_temp': -76.0, 'pressure': 732.0}
# {'id': '1888', 'terrestrial_date': '2018-02-20', 'sol': 1970, 'ls': 132.0, 'month': '5', 'min_temp': -77.0, 'pressure': 731.0}
# {'id': '1890', 'terrestrial_date': '2018-02-21', 'sol': 1971, 'ls': 132.0, 'month': '5', 'min_temp': -78.0, 'pressure': 731.0}
# {'id': '1891', 'terrestrial_date': '2018-02-22', 'sol': 1972, 'ls': 133.0, 'month': '5', 'min_temp': -78.0, 'pressure': 730.0}
# {'id': '1889', 'terrestrial_date': '2018-02-23', 'sol': 1973, 'ls': 133.0, 'month': '5', 'min_temp': -78.0, 'pressure': 730.0}
# {'id': '1892', 'terrestrial_date': '2018-02-24', 'sol': 1974, 'ls': 134.0, 'month': '5', 'min_temp': -77.0, 'pressure': 729.0}
# {'id': '1894', 'terrestrial_date': '2018-02-25', 'sol': 1975, 'ls': 134.0, 'month': '5', 'min_temp': -76.0, 'pressure': 729.0}
# {'id': '1893', 'terrestrial_date': '2018-02-26', 'sol': 1976, 'ls': 135.0, 'month': '5', 'min_temp': -77.0, 'pressure': 728.0}
# {'id': '1895', 'terrestrial_date': '2018-02-27', 'sol': 1977, 'ls': 135.0, 'month': '5', 'min_temp': -77.0, 'pressure': 727.0}

# %% [markdown]
# ### Step 3: Store the Data
#
# Assemble the scraped data into a Pandas DataFrame. The columns should have the same headings as the table on the website. Here’s an explanation of the column headings:
#
# * `id`: the identification number of a single transmission from the Curiosity rover
# * `terrestrial_date`: the date on Earth
# * `sol`: the number of elapsed sols (Martian days) since Curiosity landed on Mars
# * `ls`: the solar longitude
# * `month`: the Martian month
# * `min_temp`: the minimum temperature, in Celsius, of a single Martian day (sol)
# * `pressure`: The atmospheric pressure at Curiosity's location

# %%
# Create an empty list

# Loop through the scraped data to create a list of rows

# %%
# Create a Pandas DataFrame by using the list of rows and a list of the column names
df = pd.DataFrame(data)
# Confirm DataFrame was created successfully

df
# Out:
#         id terrestrial_date   sol     ls month  min_temp  pressure
# 0        2       2012-08-16    10  155.0     6     -75.0     739.0
# 1       13       2012-08-17    11  156.0     6     -76.0     740.0
# 2       24       2012-08-18    12  156.0     6     -76.0     741.0
# 3       35       2012-08-19    13  157.0     6     -74.0     732.0
# 4       46       2012-08-20    14  157.0     6     -74.0     740.0
# ...    ...              ...   ...    ...   ...       ...       ...
# 1862  1889       2018-02-23  1973  133.0     5     -78.0     730.0
# 1863  1892       2018-02-24  1974  134.0     5     -77.0     729.0
# 1864  1894       2018-02-25  1975  134.0     5     -76.0     729.0
# 1865  1893       2018-02-26  1976  135.0     5     -77.0     728.0
# 1866  1895       2018-02-27  1977  135.0     5     -77.0     727.0
#
# [1867 rows x 7 columns]

# %% [markdown]
# ### Step 4: Prepare Data for Analysis
#
# Examine the data types that are currently associated with each column. If necessary, cast (or convert) the data to the appropriate `datetime`, `int`, or `float` data types.
#
#   > **Hint** You can use the Pandas `astype` and `to_datetime` methods to accomplish this task.

# %%
# Examine data type of each column
print(df.dtypes)
# Out:
# id                   object
# terrestrial_date     object
# sol                   int64
# ls                  float64
# month                object
# min_temp            float64
# pressure            float64
# dtype: object

# %%
# Change data types for data analysis

df['terrestrial_date'] = pd.to_datetime(df['terrestrial_date'])


df['id'] = df['id'].astype(object)
df['sol'] = df['sol'].astype(int)
df['ls'] = df['ls'].astype(int)
df['month'] = df['month'].astype(int)
df['min_temp'] = df['min_temp'].astype(float)
df['pressure'] = df['pressure'].astype(float)

# %%
# Confirm type changes were successful by examining data types again
print(df.dtypes)
# Out:
# id                          object
# terrestrial_date    datetime64[ns]
# sol                          int64
# ls                           int64
# month                        int64
# min_temp                   float64
# pressure                   float64
# dtype: object

# %% [markdown]
# ### Step 5: Analyze the Data
#
# Analyze your dataset by using Pandas functions to answer the following questions:
#
# 1. How many months exist on Mars?
# 2. How many Martian (and not Earth) days worth of data exist in the scraped dataset?
# 3. What are the coldest and the warmest months on Mars (at the location of Curiosity)? To answer this question:
#     * Find the average the minimum daily temperature for all of the months.
#     * Plot the results as a bar chart.
# 4. Which months have the lowest and the highest atmospheric pressure on Mars? To answer this question:
#     * Find the average the daily atmospheric pressure of all the months.
#     * Plot the results as a bar chart.
# 5. About how many terrestrial (Earth) days exist in a Martian year? To answer this question:
#     * Consider how many days elapse on Earth in the time that Mars circles the Sun once.
#     * Visually estimate the result by plotting the daily minimum temperature.

# %%
# 1. How many months are there on Mars?
month_counts = df['month'].value_counts().sort_index()
month_counts
# Out:
# month
# 1     174
# 2     178
# 3     192
# 4     194
# 5     149
# 6     147
# 7     142
# 8     141
# 9     134
# 10    112
# 11    138
# 12    166
# Name: count, dtype: int64

# %%
# 2. How many Martian days' worth of data are there?
num_martian_days = df['sol'].nunique()
num_martian_days
# Out:
# 1867

# %%
# 3. What is the average low temperature by month?
average_low_temp_by_month = df.groupby('month')['min_temp'].mean()
average_low_temp_by_month
# Out:
# month
# 1    -77.160920
# 2    -79.932584
# 3    -83.307292
# 4    -82.747423
# 5    -79.308725
# 6    -75.299320
# 7    -72.281690
# 8    -68.382979
# 9    -69.171642
# 10   -71.982143
# 11   -71.985507
# 12   -74.451807
# Name: min_temp, dtype: float64

# %%
# Plot the average temperature by month
monthly_min_temps.plot(kind='bar')
plt.xlabel('month')
plt.ylabel('Temperature in Celsius')
plt.show()

# %%
# Identify the coldest and hottest months in Curiosity's location
lowest_pressure_month = avg_pressure_by_month.idxmin()
highest_pressure_month = avg_pressure_by_month.idxmax()

months = range(1, 13)

# Create the bar chart
plt.bar(months, average_low_temp_by_month)
plt.xlabel('month')
plt.ylabel('Temperature in Celsius')
plt.xticks(months)  # Set month numbers as x-tick labels

# Highlight the coldest and hottest months
plt.axvline(x=lowest_pressure_month, color='blue', linestyle='--', label='Coldest Month')
plt.axvline(x=highest_pressure_month, color='red', linestyle='--', label='Hottest Month')

plt.show()

# %%
# 4. Average pressure by Martian month
avg_pressure_by_month = df.groupby('month')['pressure'].mean()
avg_pressure_by_month
# Out:
# month
# 1     862.488506
# 2     889.455056
# 3     877.322917
# 4     806.329897
# 5     748.557047
# 6     745.054422
# 7     795.105634
# 8     873.829787
# 9     913.305970
# 10    887.312500
# 11    857.014493
# 12    842.156627
# Name: pressure, dtype: float64

# %%
# Plot the average pressure by month
avg_pressure_by_month.plot(kind='bar')
plt.xlabel('month')
plt.ylabel('Atmospheric Presssure')
plt.show()

# %%
# 5. How many terrestrial (earth) days are there in a Martian year?

# Calculate the number of terrestrial days from the first date.
df['terrestrial_days'] = (df['terrestrial_date'] - df['terrestrial_date'].min()).dt.days

# Plotting daily minimum temperature against terrestrial days.
plt.figure(figsize=(7, 5))
plt.plot(df['terrestrial_days'], df['min_temp'], label='Daily Min Temp')

# Customize x-axis labels
plt.xlabel('Number of terrestrial days')
plt.ylabel('Minimum temperature')
plt.show()

# %% [markdown]
# On average, the third month has the coldest minimum temperature on Mars, and the eighth month is the warmest. But it is always very cold there in human terms!

# %% [markdown]
# Atmospheric pressure is, on average, lowest in the sixth month and highest in the ninth.

# %% [markdown]
# The distance from peak to peak is roughly 1425-750, or 675 days. A year on Mars appears to be about 675 days from the plot. Internet search confirms that a Mars year is equivalent to 687 earth days.

# %% [markdown]
# ### Step 6: Save the Data
#
# Export the DataFrame to a CSV file.

# %%
# Write the data to a CSV
df.to_csv('mars_weather_data.csv', index=False)

# %%
browser.quit()
